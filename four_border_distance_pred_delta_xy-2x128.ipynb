# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.contrib import rnn

# %%
readfile = '~/python/tensorflow/JolleFishData/170202_pi11_SOLI_S17_F175_TR.csv'
model_path = 'ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt'

# Training parameters
learning_rate = 0.001
dropout = 0.2
n_epochs = 100
batch_size = 512
display_step = 10

# Network parameters
n_input = 4            # number of dimensions in input
n_output = 2           # number of dimensions in output
n_embedded = 256
n_per_hidden = 64     # number of nodes per hidden layer
    # Note: we require that all hidden layers have the same number of nodes
n_hidden_layers = 2    # number of hidden layers
window_length = 50    # length of lookback window to give the LSTM

# %%
def download_data(filename):
    """download the csv file stored at 'filename'.
    Drop unnecessary columns."""
    data = pd.read_csv(readfile, sep=",", header=0, index_col=4)  # 'frame' is the 5th column in the csv
    data = data.drop(['date', 'test', 'session', 'tank'], axis=1)
        # these columns are constant over the whole file
        # remaining columns: 'x', 'y', 'borderdistance', 'displacement', 'distmoved', 'speed', 'orientation', 'heading'
    return data
    
def add_wall_distances(data):
    """Add columns to dataframe 'data' that indicate fish's
    distance from each of the four walls.
    Includes sanity check to be verified by the user,
    to ensure that inferred extremum values seem reasonable."""
    min_possible_x = (data['x'] - data['borderdistance']).min()
    min_observed_x = data['x'].min()
    max_possible_x = (data['x'] + data['borderdistance']).max()
    max_observed_x = data['x'].max()
    min_possible_y = (data['y'] - data['borderdistance']).min()
    min_observed_y = data['y'].min()
    max_possible_y = (data['y'] + data['borderdistance']).max()
    max_observed_y = data['y'].max()

    # TODO: pretty-ify this to make it more user-friendly
    print('Sanity check: do these values look reasonable to you?')
    print('Inferred min x: ' + str(min_possible_x) + '; observed min x: ' + str(min_observed_x))
    print('Inferred max x: ' + str(max_possible_x) + '; observed max x: ' + str(max_observed_x))
    print('Inferred min y: ' + str(min_possible_y) + '; observed min y: ' + str(min_observed_y))
    print('Inferred max y: ' + str(max_possible_y) + '; observed max y: ' + str(max_observed_y))
    
    data['xmin_borderdistance'] = data['x'] - min_possible_x
    data['xmax_borderdistance'] = max_possible_x - data['x']
    data['ymin_borderdistance'] = data['y'] - min_possible_y
    data['ymax_borderdistance'] = max_possible_y - data['y']
    
    return data

def add_delta_position(data):
    data['delta_x'] = data['x'].diff()
    data['delta_y'] = data['y'].diff()
    
    data = data.dropna()
    
    return data

# %%
def normalize_windows(windows):
    """normalize the data in a given window, so that all points except possibly the last lie in [0,1]"""
    normalized_windows = []
    for window in windows:
        mins = window[:-1,:].min(axis=0)   # leave out the last row when normalizing
        maxes = window[:-1,:].max(axis=0)  # leave out the last row when normalizing
        normalized_window = (window-mins)/(maxes-mins)
        normalized_windows.append(normalized_window)
    return normalized_windows

def partition_windows(windows, window_length, train_percent, valid_percent, test_percent):
    n_windows = len(windows)
    possible_overlap = 2*window_length
    n_windows -= possible_overlap
    
    n_train = n_windows*train_percent//100
    n_valid = n_windows*valid_percent//100
    n_test  = n_windows*test_percent//100

    train = windows[:n_train,:,:]
    valid = windows[n_train+window_length:n_train+n_valid+window_length,:,:]
    test  = windows[n_train+n_valid+2*window_length:,:,:]
    
    return train, valid, test
    
# TODO: find way to preserve column headers within windows
def preprocess_data(data, window_length=window_length, normalize=False):
    """break into windows, each of length 'window_length'"""

    windows = []
    for index in range(len(data) - window_length):
        windows.append(np.array(data.iloc[index:index+window_length,:]))
    
    if normalize:
        windows = normalize_windows(windows)
    
    windows = np.array(windows)
    
    # 80% training, 10% test, 10% validation
    train, valid, test = partition_windows(windows, window_length, 80, 10, 10)

    # randomize the order
    np.random.shuffle(train)
    np.random.shuffle(valid)
    np.random.shuffle(test)
    
    # select data of interest:
        # 'xmin_borderdistance', 'xmax_borderdistance', 'ymin_borderdistance', 'ymax_borderdistance'
        # for input, and
        # 'x', 'y' for output
    # x is everything except last row, y is the last row
    x_train = train[:, :-1, 8:12]
    y_train = train[:,  -1,12:]
    x_valid = valid[:, :-1, 8:12]
    y_valid = valid[: , -1,12:]
    x_test  =  test[: ,:-1, 8:12]
    y_test  =  test[: , -1,12:]

    return x_train, y_train, x_valid, y_valid, x_test, y_test

# %%
def plot_fit(true_data, predicted_data):
    slope = 1
    intercept = 0

    n_points = len(true_data)
    for series_index in range(true_data.shape[1]):
        x_data = true_data[:,series_index].reshape(n_points)
        y_data = predicted_data[:,series_index].reshape(n_points)
        abline = [slope * x + intercept for x in x_data]  # line of slope 1 and y-intercept 0

        print("\nDisplaying graph for dataseries " + str(series_index) + ":")
        plt.scatter(x_data, y_data, color='black')
        plt.plot(np.unique(x_data), np.poly1d(
            np.polyfit(x_data, y_data, 1))(np.unique(x_data)), color='red')  # line of best fit
        plt.plot(x_data, abline, color='blue')  

        plt.xlabel('Actual value')
        plt.ylabel('Predicted value')
        plt.show()

# %%
# Return a random window
def get_next_window(x_data, y_data):
    index = np.random.randint(0, len(x_data))
    inputs = x_data[index,:,:]
    output = y_data[index,:] 
    return inputs, output
    
# Generate a batch of batch_size random windows
def get_new_batch(x_data, y_data, batch_size):
    inputs = np.empty((batch_size, window_length-1, n_input))
    outputs = np.empty((batch_size, n_output))
    for index in range(batch_size):
        inputs[index,:,:], outputs[index,:] = get_next_window(x_data, y_data)
    return inputs, outputs

# %%
l2_parameter = 0.001

graph = tf.Graph()

with graph.as_default():

    # Input data
    x_batch_placeholder = tf.placeholder(tf.float32,
                                      shape=(None, window_length-1, n_input))
        # None so that able to hold differently sized batches
    y_batch_placeholder = tf.placeholder(tf.float32, shape=(None, n_output))
        # None so that able to hold differently sized batches
    dropout_placeholder = tf.placeholder(tf.float32)

    # Variables to be trained
    weights = tf.Variable(tf.truncated_normal([n_per_hidden, n_output]))
    biases = tf.Variable(tf.zeros([n_output]))
    weights2 = tf.Variable(tf.truncated_normal([n_input, n_embedded]))
    
    # Build graph
    cells = []
    for _ in range(n_hidden_layers):
        cell = rnn.BasicLSTMCell(n_per_hidden)
        cell = rnn.DropoutWrapper(cell, output_keep_prob=1.0 - dropout_placeholder)
        cells.append(cell)
    cell = rnn.MultiRNNCell(cells)
    
    
    # Define ops to run forward pass
    stacks = []
    for i in range(window_length-1):
        stacks.append(tf.nn.relu(tf.matmul(x_batch_placeholder[:,i,:], weights2)))
    embedd = tf.stack(stacks, axis=1)
    print(embedd.shape)
    outputs, states = tf.nn.dynamic_rnn(cell, embedd, dtype=tf.float32)
    logits = tf.matmul(outputs[:,-1,:], weights) + biases
    
    # Define cost and optimizer
    cost = tf.sqrt(tf.reduce_mean(tf.squared_difference(logits, y_batch_placeholder)))+l2_parameter*(tf.nn.l2_loss(weights)+tf.nn.l2_loss(biases)+tf.nn.l2_loss(weights2))  # cost function is rms
    optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(cost)
    
    # Define op to initialize global variables
    init = tf.global_variables_initializer()
    
    # Define Saver op class to save and restore model
    saver = tf.train.Saver()
# Out:
# (?, 49, 128)

# %%
def train_model(
    n_epochs=n_epochs,
    display_step=display_step,
    learning_rate=learning_rate,
    batch_size=batch_size,
    graph=graph,
    restore_from_save=True,
    restore_path=model_path,
    save_when_finished=True,
    save_path=model_path):
    
    # Launch the graph
    with tf.Session(graph=graph) as sess:
        if restore_from_save:
            try:
                saver.restore(sess, restore_path)
                print("Model successfully restored from %s.\nResuming training." % restore_path)
            except tf.errors.NotFoundError:
                print("Save file not found.\nInitializing graph from scratch instead.")
                sess.run(init)
                print("Global variables initialized.\nCommencing training.")
        else:
            sess.run(init)
            print("Global variables initialized.\nCommencing training.")

        # Keep training until reach max iterations
        for epoch_idx in range(n_epochs):
            _x_batch, _y_batch = get_new_batch(x_train, y_train, batch_size)

            # Run optimization op (backprop)
            feed_dict = {x_batch_placeholder: _x_batch, y_batch_placeholder: _y_batch, dropout_placeholder: dropout}
            _train_cost, _ = sess.run([cost, optimizer], feed_dict=feed_dict)

            if epoch_idx % display_step == 0:
                _valid_cost = sess.run(
                    cost, feed_dict={x_batch_placeholder: x_valid, y_batch_placeholder: y_valid, dropout_placeholder: dropout})
                print("Epoch " + str(epoch_idx) + ", Minibatch cost = " + \
                      "{:.6f}".format(_train_cost))
                print("Epoch " + str(epoch_idx) + ", Validation set cost = " + \
                      "{:.6f}".format(_valid_cost))

        if save_when_finished:
            # Save model weights to disk
            _save_path = saver.save(sess, save_path)
            print("Model saved in file: %s" % _save_path)

        # Plot fit on validation data
        print("\nCurrent validation performance:")
        plot_fit(y_valid, logits.eval(feed_dict={x_batch_placeholder: x_valid, dropout_placeholder: 0}))

# %%
def extract_wall_distances(prediction, seed):
    new_wall_distances = np.zeros(4)
    new_wall_distances[0] = seed[-1,0]+prediction[0,0]  # new distance from min x
    new_wall_distances[1] = seed[-1,1]-prediction[0,0]  # new distance from max x
    new_wall_distances[2] = seed[-1,2]+prediction[0,1]  # new distance from min y
    new_wall_distances[3] = seed[-1,3]-prediction[0,1]  # new distance from max y
    
    new_coords = np.array([new_wall_distances[0], new_wall_distances[2]])
    
    return new_wall_distances, new_coords
    
def generate_next_point(seed, sess):
    random_scalar = 1/4
    feed_dict = {x_batch_placeholder: seed, dropout_placeholder: 0}
    _logits = logits.eval(session=sess, feed_dict=feed_dict)
    _logits = _logits + np.random.randn(1,2)*random_scalar
    # print (_logits.shape,type(_logits))
    return _logits
    
def shift_seed(old_seed, new_row):
    return np.vstack([old_seed[1:,:], new_row])
    
def generate_prediction(seed, prediction_length, restore_path=model_path, progress_counter=20):
    """Starting from an unnormalized seed sequence and generate a new sequence of positions"
    Params:
        seed: ndarray, shape (1, window_length-1, n_input)
        prediction_length: integer, number of desired timesteps to generate
        restore_path: string, location from which to load saved graph state
        progress_counter: integer, indicates number of intervals to print progress in generating sequence
    Returns:
        array of predicted locations, of shape shape (prediction_length, n_output)
    """
    with tf.Session(graph=graph) as sess:
        # load the variables
        try:
            saver.restore(sess, restore_path)
            print("Model successfully restored from %s.\nGenerating sequence." % restore_path)
        except tf.errors.NotFoundError:  # TODO: add type of error
            print("Save file not found.\nExiting.")
            return
        
        predictions = []
        show_interval = prediction_length//progress_counter
        
        for index in range(prediction_length):
            if index % show_interval == 0:
                print("Generated", index, "of", prediction_length, "data points.")
            batch_seed = seed.reshape(1, window_length-1, n_input)  # cast to batch format (batch of size 1)
            prediction = generate_next_point(batch_seed, sess)
            wall_distances, pred_coords = extract_wall_distances(prediction, seed)
            predictions.append(pred_coords)
            seed = shift_seed(seed, wall_distances)
        print("Done!")
        
        return np.array(predictions)

# %%
# Load data, add required columns
all_data = download_data(readfile)
all_data = add_wall_distances(all_data)
all_data = add_delta_position(all_data)
# Out:
# Sanity check: do these values look reasonable to you?
# Inferred min x: 0.0; observed min x: 10.2
# Inferred max x: 775.0; observed max x: 772.4
# Inferred min y: 0.0; observed min y: 3.9
# Inferred max y: 515.3; observed max y: 507.4

# %%
# Create training, validation, and test sets
x_train, y_train, x_valid, y_valid, x_test, y_test = preprocess_data(
    all_data, window_length=window_length, normalize=False)

# %%
train_model(n_epochs=200,display_step=10,learning_rate=0.01, restore_from_save=False)
# Out:
# Global variables initialized.
# Commencing training.
# Epoch 0, Minibatch cost = 3.866500
# Epoch 0, Validation set cost = 3.745833
# Epoch 10, Minibatch cost = 3.288702
# Epoch 10, Validation set cost = 3.266451
# Epoch 20, Minibatch cost = 3.055071
# Epoch 20, Validation set cost = 2.995085
# Epoch 30, Minibatch cost = 2.990436
# Epoch 30, Validation set cost = 2.862905
# Epoch 40, Minibatch cost = 2.957996
# Epoch 40, Validation set cost = 2.921077
# Epoch 50, Minibatch cost = 2.958490
# Epoch 50, Validation set cost = 2.767908
# Epoch 60, Minibatch cost = 3.103451
# Epoch 60, Validation set cost = 2.886587
# Epoch 70, Minibatch cost = 3.127445
# Epoch 70, Validation set cost = 2.843311
# Epoch 80, Minibatch cost = 2.682194
# Epoch 80, Validation set cost = 2.798267
# Epoch 90, Minibatch cost = 3.018350
# Epoch 90, Validation set cost = 2.546698
# Epoch 100, Minibatch cost = 2.906936
# Epoch 100, Validation set cost = 2.543051
# Epoch 110, Minibatch cost = 2.766016
# Epoch 110, Validation set cost = 2.684008
# Epoch 120, Minibatch cost = 2.570150
# Epoch 120, Validation set cost = 2.558403
# Epoch 130, Minibatch cost = 2.718323
# Epoch 130, Validation set cost = 2.515168
# Epoch 140, Minibatch cost = 2.479019
# Epoch 140, Validation set cost = 2.509148
# Epoch 150, Minibatch cost = 2.683219
# Epoch 150, Validation set cost = 2.621382
# Epoch 160, Minibatch cost = 2.511749
# Epoch 160, Validation set cost = 2.450585
# Epoch 170, Minibatch cost = 2.616275
# Epoch 170, Validation set cost = 2.342625
# Epoch 180, Minibatch cost = 2.366309
# Epoch 180, Validation set cost = 2.306127
# Epoch 190, Minibatch cost = 2.527819
# Epoch 190, Validation set cost = 2.458396
# Model saved in file: ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
#
# Current validation performance:
#
# Displaying graph for dataseries 0:
# Displaying graph for dataseries 1:

# %%
train_model(n_epochs=200,display_step=10,learning_rate=0.001, restore_from_save=True)
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Resuming training.
# Epoch 0, Minibatch cost = 2.601375
# Epoch 0, Validation set cost = 2.455835
# Epoch 10, Minibatch cost = 2.709709
# Epoch 10, Validation set cost = 2.439287
# Epoch 20, Minibatch cost = 2.504581
# Epoch 20, Validation set cost = 2.203052
# Epoch 30, Minibatch cost = 2.344578
# Epoch 30, Validation set cost = 2.355909
# Epoch 40, Minibatch cost = 2.387167
# Epoch 40, Validation set cost = 2.186301
# Epoch 50, Minibatch cost = 2.387004
# Epoch 50, Validation set cost = 2.154756
# Epoch 60, Minibatch cost = 2.250487
# Epoch 60, Validation set cost = 2.465473
# Epoch 70, Minibatch cost = 2.395665
# Epoch 70, Validation set cost = 2.363204
# Epoch 80, Minibatch cost = 2.212458
# Epoch 80, Validation set cost = 2.190989
# Epoch 90, Minibatch cost = 2.288987
# Epoch 90, Validation set cost = 2.438413
# Epoch 100, Minibatch cost = 2.151489
# Epoch 100, Validation set cost = 2.136058
# Epoch 110, Minibatch cost = 2.280309
# Epoch 110, Validation set cost = 2.212264
# Epoch 120, Minibatch cost = 2.153524
# Epoch 120, Validation set cost = 2.083288
# Epoch 130, Minibatch cost = 2.227249
# Epoch 130, Validation set cost = 2.120435
# Epoch 140, Minibatch cost = 2.209007
# Epoch 140, Validation set cost = 2.354116
# Epoch 150, Minibatch cost = 2.178377
# Epoch 150, Validation set cost = 2.109174
# Epoch 160, Minibatch cost = 2.294318
# Epoch 160, Validation set cost = 2.017345
# Epoch 170, Minibatch cost = 2.087633
# Epoch 170, Validation set cost = 2.075705
# Epoch 180, Minibatch cost = 2.137534
# Epoch 180, Validation set cost = 2.150603
# Epoch 190, Minibatch cost = 2.214250
# Epoch 190, Validation set cost = 2.032851
# Model saved in file: ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
#
# Current validation performance:
#
# Displaying graph for dataseries 0:
# Displaying graph for dataseries 1:

# %%
train_model(n_epochs=300,display_step=10,learning_rate=0.0001, restore_from_save=True)
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Resuming training.
# Epoch 0, Minibatch cost = 2.202836
# Epoch 0, Validation set cost = 1.976240
# Epoch 10, Minibatch cost = 2.089878
# Epoch 10, Validation set cost = 2.137697
# Epoch 20, Minibatch cost = 2.272909
# Epoch 20, Validation set cost = 2.144933
# Epoch 30, Minibatch cost = 2.180379
# Epoch 30, Validation set cost = 2.076130
# Epoch 40, Minibatch cost = 2.077430
# Epoch 40, Validation set cost = 2.134602
# Epoch 50, Minibatch cost = 2.057528
# Epoch 50, Validation set cost = 2.138757
# Epoch 60, Minibatch cost = 2.059489
# Epoch 60, Validation set cost = 2.297363
# Epoch 70, Minibatch cost = 2.142275
# Epoch 70, Validation set cost = 1.991557
# Epoch 80, Minibatch cost = 2.049277
# Epoch 80, Validation set cost = 2.059683
# Epoch 90, Minibatch cost = 2.006504
# Epoch 90, Validation set cost = 1.919260
# Epoch 100, Minibatch cost = 2.154736
# Epoch 100, Validation set cost = 2.257428
# Epoch 110, Minibatch cost = 2.073835
# Epoch 110, Validation set cost = 1.923389
# Epoch 120, Minibatch cost = 2.156623
# Epoch 120, Validation set cost = 2.024706
# Epoch 130, Minibatch cost = 2.193280
# Epoch 130, Validation set cost = 1.942764
# Epoch 140, Minibatch cost = 2.113226
# Epoch 140, Validation set cost = 1.983241
# Epoch 150, Minibatch cost = 2.027586
# Epoch 150, Validation set cost = 2.110553
# Epoch 160, Minibatch cost = 2.122965
# Epoch 160, Validation set cost = 1.975021
# Epoch 170, Minibatch cost = 2.227168
# Epoch 170, Validation set cost = 2.010015
# Epoch 180, Minibatch cost = 2.051720
# Epoch 180, Validation set cost = 1.911325
# Epoch 190, Minibatch cost = 2.077691
# Epoch 190, Validation set cost = 2.050410
# Epoch 200, Minibatch cost = 1.973913
# Epoch 200, Validation set cost = 1.960222
# Epoch 210, Minibatch cost = 1.951838
# Epoch 210, Validation set cost = 1.907712
# Epoch 220, Minibatch cost = 2.073258
# Epoch 220, Validation set cost = 1.880561
# Epoch 230, Minibatch cost = 2.052130
# Epoch 230, Validation set cost = 2.073003
# Epoch 240, Minibatch cost = 2.000628
# Epoch 240, Validation set cost = 1.912671
# Epoch 250, Minibatch cost = 2.085683
# Epoch 250, Validation set cost = 1.931850
# Epoch 260, Minibatch cost = 1.966508
# Epoch 260, Validation set cost = 1.967300
# Epoch 270, Minibatch cost = 1.967903
# Epoch 270, Validation set cost = 1.924125
# Epoch 280, Minibatch cost = 2.042698
# Epoch 280, Validation set cost = 1.874945
# Epoch 290, Minibatch cost = 2.086023
# Epoch 290, Validation set cost = 1.903270
# Model saved in file: ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
#
# Current validation performance:
#
# Displaying graph for dataseries 0:
# Displaying graph for dataseries 1:

# %%
filename = 'predict_window_50-2.csv'
seed = x_train[101]
predictions = generate_prediction(seed, 5000, restore_path=model_path, progress_counter=20)
np.savetxt(filename, predictions, delimiter=",")
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Generating sequence.
# Generated 0 of 5000 data points.
# Generated 250 of 5000 data points.
# Generated 500 of 5000 data points.
# Generated 750 of 5000 data points.
# Generated 1000 of 5000 data points.
# Generated 1250 of 5000 data points.
# Generated 1500 of 5000 data points.
# Generated 1750 of 5000 data points.
# Generated 2000 of 5000 data points.
# Generated 2250 of 5000 data points.
# Generated 2500 of 5000 data points.
# Generated 2750 of 5000 data points.
# Generated 3000 of 5000 data points.
# Generated 3250 of 5000 data points.
# Generated 3500 of 5000 data points.
# Generated 3750 of 5000 data points.
# Generated 4000 of 5000 data points.
# Generated 4250 of 5000 data points.
# Generated 4500 of 5000 data points.
# Generated 4750 of 5000 data points.
# Done!

# %%
# TODO: DELETE THIS SANDBOX
# NOTE: THIS IS THE SOLUTION
mini_data = all_data.iloc[:100,:]
mycolumn_types = [str(mini_data[x].dtype) for x in mini_data]
mydtypes = list(zip(mini_data.columns.values,mycolumn_types))
print(np.array(mini_data,dtype=mydtypes)['x'][:,0])
print('---------------')
print(np.array(mini_data,dtype=mydtypes))
print('---------------')
print(np.array(mini_data))
print('---------------')
np.array(mini_data,dtype=mydtypes)
# Out:
# [ 391.8  393.9  394.4  397.4  401.   403.6  405.6  408.7  412.8  415.8
#   417.9  421.4  426.5  430.6  434.2  436.7  439.3  442.3  446.9  450.5
#   454.1  459.7  467.3  473.5  479.6  484.7  489.3  493.9  500.5  507.7
#   514.3  519.9  527.   534.2  541.3  546.9  552.6  556.6  560.7  564.8
#   568.4  571.9  574.5  577.   579.6  582.1  583.7  586.2  590.3  594.4
#   600.   607.1  613.3  618.9  623.5  628.1  632.1  636.2  641.3  646.9
#   652.   657.1  660.7  663.8  666.3  667.9  669.4  669.9  670.4  671.4
#   671.9  672.4  673.5  673.5  674.   674.5  674.5  675.   675.5  676.5
#   676.5  676.5  676.5  676.5  677.   678.1  677.6  681.6  686.7  690.8
#   694.4  699.5  703.6  707.7  711.2  714.8  718.9  723.   726.   728.6]
# ---------------
# [[ (  3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02)
#   (  2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02)
#   (  2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02)
#   ...,
#   (  3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02)
#   (  5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01)
#   (  4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01)]
#  [ (  3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02)
#   (  2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02)
#   (  2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02)
#   ...,
#   (  3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02)
#   (  2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00)
#   (  4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01)]
#  [ (  3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02)
#   (  2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02)
#   (  2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02)
#   ...,
#   (  2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02)
#   (  5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01)
#   (  9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01)]
#  ...,
#  [ (  7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02)
#   (  1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02)
#   (  5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01)
#   ...,
#   (  3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02)
#   (  4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00)
#   (  6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00)]
#  [ (  7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02)
#   (  1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02)
#   (  4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01)
#   ...,
#   (  3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02)
#   (  3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00)
#   (  5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00)]
#  [ (  7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02)
#   (  2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02)
#   (  4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01)
#   ...,
#   (  3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02)
#   (  2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00)
#   (  5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00)]]
# ---------------
# [[  3.91800000e+02   2.14400000e+02   2.14400000e+02 ...,   3.00900000e+02
#     5.00000000e-01   4.00000000e-01]
#  [  3.93900000e+02   2.14800000e+02   2.14800000e+02 ...,   3.00500000e+02
#     2.10000000e+00   4.00000000e-01]
#  [  3.94400000e+02   2.15700000e+02   2.15700000e+02 ...,   2.99600000e+02
#     5.00000000e-01   9.00000000e-01]
#  ...,
#  [  7.23000000e+02   1.91300000e+02   5.20000000e+01 ...,   3.24000000e+02
#     4.10000000e+00   6.10000000e+00]
#  [  7.26000000e+02   1.96900000e+02   4.90000000e+01 ...,   3.18400000e+02
#     3.00000000e+00   5.60000000e+00]
#  [  7.28600000e+02   2.02200000e+02   4.64000000e+01 ...,   3.13100000e+02
#     2.60000000e+00   5.30000000e+00]]
# ---------------
# array([[ (  3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02,   3.91800000e+02),
#         (  2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02),
#         (  2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02,   2.14400000e+02),
#         ...,
#         (  3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02,   3.00900000e+02),
#         (  5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01),
#         (  4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01)],
#        [ (  3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02,   3.93900000e+02),
#         (  2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02),
#         (  2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02,   2.14800000e+02),
#         ...,
#         (  3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02,   3.00500000e+02),
#         (  2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00,   2.10000000e+00),
#         (  4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01,   4.00000000e-01)],
#        [ (  3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02,   3.94400000e+02),
#         (  2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02),
#         (  2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02,   2.15700000e+02),
#         ...,
#         (  2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02,   2.99600000e+02),
#         (  5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01,   5.00000000e-01),
#         (  9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01,   9.00000000e-01)],
#        ...,
#        [ (  7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02,   7.23000000e+02),
#         (  1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02,   1.91300000e+02),
#         (  5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01,   5.20000000e+01),
#         ...,
#         (  3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02,   3.24000000e+02),
#         (  4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00,   4.10000000e+00),
#         (  6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00,   6.10000000e+00)],
#        [ (  7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02,   7.26000000e+02),
#         (  1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02,   1.96900000e+02),
#         (  4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01),
#         ...,
#         (  3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02,   3.18400000e+02),
#         (  3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00,   3.00000000e+00),
#         (  5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00,   5.60000000e+00)],
#        [ (  7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02,   7.28600000e+02),
#         (  2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02,   2.02200000e+02),
#         (  4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01,   4.64000000e+01),
#         ...,
#         (  3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02,   3.13100000e+02),
#         (  2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00,   2.60000000e+00),
#         (  5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00,   5.30000000e+00)]],
#       dtype=[('x', '<f8'), ('y', '<f8'), ('borderdistance', '<f8'), ('displacement', '<f8'), ('distmoved', '<f8'), ('speed', '<f8'), ('orientation', '<f8'), ('heading', '<f8'), ('xmin_borderdistance', '<f8'), ('xmax_borderdistance', '<f8'), ('ymin_borderdistance', '<f8'), ('ymax_borderdistance', '<f8'), ('delta_x', '<f8'), ('delta_y', '<f8')])

# %%
mini_data = all_data.iloc[:100,:]
mycolumn_types = [str(mini_data[x].dtype) for x in mini_data]
mydtypes = list(zip(mini_data.columns.values,mycolumn_types))
#print(np.array(mini_data.values,dtype=mydtypes, copy=False))
print(mydtypes)
type(mini_data.values)
# Out:
# [('x', 'float64'), ('y', 'float64'), ('borderdistance', 'float64'), ('displacement', 'float64'), ('distmoved', 'float64'), ('speed', 'float64'), ('orientation', 'float64'), ('heading', 'float64'), ('xmin_borderdistance', 'float64'), ('xmax_borderdistance', 'float64'), ('ymin_borderdistance', 'float64'), ('ymax_borderdistance', 'float64'), ('delta_x', 'float64'), ('delta_y', 'float64')]
# numpy.ndarray

# %%
mycolumn_types = [str(mini_data[x].dtype) for x in mini_data]
mycolumn_names = list(mini_data.columns.values)
zipped = list(zip(mycolumn_names,mycolumn_types))
print(zipped)
np.dtype(zipped)
np.dtype([('f1', np.uint), ('f2', np.int32)])
# Out:
# [('x', 'float64'), ('y', 'float64'), ('borderdistance', 'float64'), ('displacement', 'float64'), ('distmoved', 'float64'), ('speed', 'float64'), ('orientation', 'float64'), ('heading', 'float64'), ('xmin_borderdistance', 'float64'), ('xmax_borderdistance', 'float64'), ('ymin_borderdistance', 'float64'), ('ymax_borderdistance', 'float64'), ('delta_x', 'float64'), ('delta_y', 'float64')]
# dtype([('f1', '<u8'), ('f2', '<i4')])

# %%
len(all_data)
# Out:
# 14798

# %%
train_model(n_epochs=500,display_step=10,learning_rate=0.00001, restore_from_save=True)
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Resuming training.
# Epoch 0, Minibatch cost = 1.988807
# Epoch 0, Validation set cost = 1.911442
# Epoch 1, Minibatch cost = 2.004714
# Epoch 1, Validation set cost = 1.902990
# Epoch 2, Minibatch cost = 2.036851
# Epoch 2, Validation set cost = 1.917483
# Epoch 3, Minibatch cost = 2.001783
# Epoch 3, Validation set cost = 1.906150
# Epoch 4, Minibatch cost = 2.032369
# Epoch 4, Validation set cost = 2.094513
# Epoch 5, Minibatch cost = 2.039375
# Epoch 5, Validation set cost = 2.003949
# Epoch 6, Minibatch cost = 2.120942
# Epoch 6, Validation set cost = 1.938075
# Epoch 7, Minibatch cost = 2.065481
# Epoch 7, Validation set cost = 1.983036
# Epoch 8, Minibatch cost = 1.973800
# Epoch 8, Validation set cost = 1.935004
# Epoch 9, Minibatch cost = 1.987033
# Epoch 9, Validation set cost = 1.952705
# Epoch 10, Minibatch cost = 1.959068
# Epoch 10, Validation set cost = 2.022125
# Epoch 11, Minibatch cost = 2.136031
# Epoch 11, Validation set cost = 2.019770
# Epoch 12, Minibatch cost = 2.066693
# Epoch 12, Validation set cost = 1.942918
# Epoch 13, Minibatch cost = 1.953986
# Epoch 13, Validation set cost = 1.956843
# Epoch 14, Minibatch cost = 1.951054
# Epoch 14, Validation set cost = 1.958462
# Epoch 15, Minibatch cost = 1.917748
# Epoch 15, Validation set cost = 1.912683
# Epoch 16, Minibatch cost = 2.053437
# Epoch 16, Validation set cost = 2.062277
# Epoch 17, Minibatch cost = 2.033425
# Epoch 17, Validation set cost = 2.018562
# Epoch 18, Minibatch cost = 1.951869
# Epoch 18, Validation set cost = 1.887843
# Epoch 19, Minibatch cost = 1.935875
# Epoch 19, Validation set cost = 1.915192
# Epoch 20, Minibatch cost = 1.916067
# Epoch 20, Validation set cost = 1.904624
# Epoch 21, Minibatch cost = 1.966061
# Epoch 21, Validation set cost = 1.974727
# Epoch 22, Minibatch cost = 2.121056
# Epoch 22, Validation set cost = 1.982112
# Epoch 23, Minibatch cost = 2.019909
# Epoch 23, Validation set cost = 1.957611
# Epoch 24, Minibatch cost = 1.983244
# Epoch 24, Validation set cost = 1.930740
# Epoch 25, Minibatch cost = 2.006014
# Epoch 25, Validation set cost = 1.958257
# Epoch 26, Minibatch cost = 2.125816
# Epoch 26, Validation set cost = 2.004547
# Epoch 27, Minibatch cost = 2.077760
# Epoch 27, Validation set cost = 1.984453
# Epoch 28, Minibatch cost = 2.037378
# Epoch 28, Validation set cost = 1.990002
# Epoch 29, Minibatch cost = 2.026690
# Epoch 29, Validation set cost = 2.063539
# Epoch 30, Minibatch cost = 2.045793
# Epoch 30, Validation set cost = 1.963296
# Epoch 31, Minibatch cost = 2.007812
# Epoch 31, Validation set cost = 1.988683
# Epoch 32, Minibatch cost = 1.955326
# Epoch 32, Validation set cost = 1.940234
# Epoch 33, Minibatch cost = 1.920288
# Epoch 33, Validation set cost = 1.904621
# Epoch 34, Minibatch cost = 1.883433
# Epoch 34, Validation set cost = 1.923546
# Epoch 35, Minibatch cost = 1.887988
# Epoch 35, Validation set cost = 1.969286
# Epoch 36, Minibatch cost = 1.895190
# Epoch 36, Validation set cost = 1.926933
# Epoch 37, Minibatch cost = 2.072929
# Epoch 37, Validation set cost = 1.905062
# Epoch 38, Minibatch cost = 2.050623
# Epoch 38, Validation set cost = 1.901412
# Epoch 39, Minibatch cost = 2.050865
# Epoch 39, Validation set cost = 1.966930
# Epoch 40, Minibatch cost = 1.983404
# Epoch 40, Validation set cost = 1.968217
# Epoch 41, Minibatch cost = 2.116449
# Epoch 41, Validation set cost = 1.902088
# Epoch 42, Minibatch cost = 2.036752
# Epoch 42, Validation set cost = 1.916669
# Epoch 43, Minibatch cost = 1.906639
# Epoch 43, Validation set cost = 1.883802
# Epoch 44, Minibatch cost = 1.918938
# Epoch 44, Validation set cost = 1.922786
# Epoch 45, Minibatch cost = 1.928741
# Epoch 45, Validation set cost = 2.084233
# Epoch 46, Minibatch cost = 1.958406
# Epoch 46, Validation set cost = 1.974672
# Epoch 47, Minibatch cost = 2.000050
# Epoch 47, Validation set cost = 1.910848
# Epoch 48, Minibatch cost = 1.968712
# Epoch 48, Validation set cost = 1.905547
# Epoch 49, Minibatch cost = 2.009904
# Epoch 49, Validation set cost = 2.034641
# Epoch 50, Minibatch cost = 2.064161
# Epoch 50, Validation set cost = 1.927634
# Epoch 51, Minibatch cost = 2.056883
# Epoch 51, Validation set cost = 1.883274
# Epoch 52, Minibatch cost = 2.141705
# Epoch 52, Validation set cost = 1.889777
# Epoch 53, Minibatch cost = 2.128195
# Epoch 53, Validation set cost = 1.947977
# Epoch 54, Minibatch cost = 2.000306
# Epoch 54, Validation set cost = 1.818307
# Epoch 55, Minibatch cost = 2.127087
# Epoch 55, Validation set cost = 1.888344
# Epoch 56, Minibatch cost = 1.948147
# Epoch 56, Validation set cost = 1.884979
# Epoch 57, Minibatch cost = 2.026164
# Epoch 57, Validation set cost = 1.950815
# Epoch 58, Minibatch cost = 1.924736
# Epoch 58, Validation set cost = 1.881820
# Epoch 59, Minibatch cost = 1.941508
# Epoch 59, Validation set cost = 1.885051
# Epoch 60, Minibatch cost = 2.030900
# Epoch 60, Validation set cost = 1.904236
# Epoch 61, Minibatch cost = 1.928735
# Epoch 61, Validation set cost = 1.872462
# Epoch 62, Minibatch cost = 1.884631
# Epoch 62, Validation set cost = 1.869452
# Epoch 63, Minibatch cost = 1.994711
# Epoch 63, Validation set cost = 2.066592
# Epoch 64, Minibatch cost = 2.105255
# Epoch 64, Validation set cost = 1.866057
# Epoch 65, Minibatch cost = 1.937608
# Epoch 65, Validation set cost = 1.951751
# Epoch 66, Minibatch cost = 1.996771
# Epoch 66, Validation set cost = 2.032477
# Epoch 67, Minibatch cost = 2.017868
# Epoch 67, Validation set cost = 1.894838
# Epoch 68, Minibatch cost = 1.955148
# Epoch 68, Validation set cost = 1.881254
# Epoch 69, Minibatch cost = 1.987296
# Epoch 69, Validation set cost = 1.963336
# Epoch 70, Minibatch cost = 1.907579
# Epoch 70, Validation set cost = 1.915440
# Epoch 71, Minibatch cost = 1.958710
# Epoch 71, Validation set cost = 1.892721
# Epoch 72, Minibatch cost = 1.929885
# Epoch 72, Validation set cost = 1.944957
# Epoch 73, Minibatch cost = 1.894070
# Epoch 73, Validation set cost = 1.968019
# Epoch 74, Minibatch cost = 1.930122
# Epoch 74, Validation set cost = 1.833619
# Epoch 75, Minibatch cost = 2.057227
# Epoch 75, Validation set cost = 2.075579
# Epoch 76, Minibatch cost = 1.978406
# Epoch 76, Validation set cost = 2.007369
# Epoch 77, Minibatch cost = 1.935011
# Epoch 77, Validation set cost = 1.959494
# Epoch 78, Minibatch cost = 2.093481
# Epoch 78, Validation set cost = 1.960525
# Epoch 79, Minibatch cost = 2.082751
# Epoch 79, Validation set cost = 1.930507
# Epoch 80, Minibatch cost = 1.992620
# Epoch 80, Validation set cost = 1.961392
# Epoch 81, Minibatch cost = 2.056237
# Epoch 81, Validation set cost = 1.878564
# Epoch 82, Minibatch cost = 1.932538
# Epoch 82, Validation set cost = 1.867050
# Epoch 83, Minibatch cost = 1.941856
# Epoch 83, Validation set cost = 1.963614
# Epoch 84, Minibatch cost = 1.856366
# Epoch 84, Validation set cost = 1.975395
# Epoch 85, Minibatch cost = 2.048858
# Epoch 85, Validation set cost = 1.890958
# Epoch 86, Minibatch cost = 1.929829
# Epoch 86, Validation set cost = 1.928966
# Epoch 87, Minibatch cost = 2.012522
# Epoch 87, Validation set cost = 1.928804
# Epoch 88, Minibatch cost = 2.009641
# Epoch 88, Validation set cost = 1.890651
# Epoch 89, Minibatch cost = 2.020865
# Epoch 89, Validation set cost = 1.964786
# Epoch 90, Minibatch cost = 1.943819
# Epoch 90, Validation set cost = 1.917194
# Epoch 91, Minibatch cost = 1.902256
# Epoch 91, Validation set cost = 2.014153
# Epoch 92, Minibatch cost = 2.086478
# Epoch 92, Validation set cost = 1.945369
# Epoch 93, Minibatch cost = 1.921046
# Epoch 93, Validation set cost = 1.977593
# Epoch 94, Minibatch cost = 1.957704
# Epoch 94, Validation set cost = 1.977877
# Epoch 95, Minibatch cost = 1.923449
# Epoch 95, Validation set cost = 1.958161
# Epoch 96, Minibatch cost = 1.885128
# Epoch 96, Validation set cost = 1.980237
# Epoch 97, Minibatch cost = 1.976669
# Epoch 97, Validation set cost = 1.893671
# Epoch 98, Minibatch cost = 1.953398
# Epoch 98, Validation set cost = 1.893981
# Epoch 99, Minibatch cost = 1.906279
# Epoch 99, Validation set cost = 1.931954
# Epoch 100, Minibatch cost = 1.923511
# Epoch 100, Validation set cost = 1.921826
# Epoch 101, Minibatch cost = 1.888338
# Epoch 101, Validation set cost = 1.939832
# Epoch 102, Minibatch cost = 2.013502
# Epoch 102, Validation set cost = 1.883327
# Epoch 103, Minibatch cost = 2.023293
# Epoch 103, Validation set cost = 2.023645
# Epoch 104, Minibatch cost = 2.063312
# Epoch 104, Validation set cost = 1.910574
# Epoch 105, Minibatch cost = 2.084817
# Epoch 105, Validation set cost = 1.899337
# Epoch 106, Minibatch cost = 1.995134
# Epoch 106, Validation set cost = 1.898477
# Epoch 107, Minibatch cost = 2.003273
# Epoch 107, Validation set cost = 1.883529
# Epoch 108, Minibatch cost = 1.996832
# Epoch 108, Validation set cost = 1.843047
# Epoch 109, Minibatch cost = 1.996653
# Epoch 109, Validation set cost = 1.961606
# Epoch 110, Minibatch cost = 1.938015
# Epoch 110, Validation set cost = 1.945921
# Epoch 111, Minibatch cost = 2.025310
# Epoch 111, Validation set cost = 1.877303
# Epoch 112, Minibatch cost = 1.890330
# Epoch 112, Validation set cost = 1.889684
# Epoch 113, Minibatch cost = 2.072742
# Epoch 113, Validation set cost = 1.898448
# Epoch 114, Minibatch cost = 2.007488
# Epoch 114, Validation set cost = 1.851582
# Epoch 115, Minibatch cost = 1.941521
# Epoch 115, Validation set cost = 1.821384
# Epoch 116, Minibatch cost = 1.886984
# Epoch 116, Validation set cost = 1.905523
# Epoch 117, Minibatch cost = 2.003864
# Epoch 117, Validation set cost = 1.923100
# Epoch 118, Minibatch cost = 1.997345
# Epoch 118, Validation set cost = 1.845834
# Epoch 119, Minibatch cost = 1.978588
# Epoch 119, Validation set cost = 1.841657
# Epoch 120, Minibatch cost = 1.961091
# Epoch 120, Validation set cost = 1.876028
# Epoch 121, Minibatch cost = 2.003092
# Epoch 121, Validation set cost = 1.853229
# Epoch 122, Minibatch cost = 1.938606
# Epoch 122, Validation set cost = 1.819482
# Epoch 123, Minibatch cost = 1.917531
# Epoch 123, Validation set cost = 1.828583
# Epoch 124, Minibatch cost = 1.894148
# Epoch 124, Validation set cost = 2.004070
# Epoch 125, Minibatch cost = 1.940579
# Epoch 125, Validation set cost = 1.808506
# Epoch 126, Minibatch cost = 1.863351
# Epoch 126, Validation set cost = 1.872175
# Epoch 127, Minibatch cost = 1.907993
# Epoch 127, Validation set cost = 1.899946
# Epoch 128, Minibatch cost = 1.912412
# Epoch 128, Validation set cost = 1.933105
# Epoch 129, Minibatch cost = 1.933156
# Epoch 129, Validation set cost = 1.855628
# Epoch 130, Minibatch cost = 1.946685
# Epoch 130, Validation set cost = 1.827244
# Epoch 131, Minibatch cost = 1.889205
# Epoch 131, Validation set cost = 1.822614
# Epoch 132, Minibatch cost = 1.911832
# Epoch 132, Validation set cost = 1.800961
# Epoch 133, Minibatch cost = 1.831873
# Epoch 133, Validation set cost = 1.820452
# Epoch 134, Minibatch cost = 1.898192
# Epoch 134, Validation set cost = 1.880361
# Epoch 135, Minibatch cost = 2.042134
# Epoch 135, Validation set cost = 1.927783
# Epoch 136, Minibatch cost = 1.961593
# Epoch 136, Validation set cost = 1.862743
# Epoch 137, Minibatch cost = 1.918691
# Epoch 137, Validation set cost = 1.890511
# Epoch 138, Minibatch cost = 1.891043
# Epoch 138, Validation set cost = 1.890069
# Epoch 139, Minibatch cost = 1.908395
# Epoch 139, Validation set cost = 1.921531
# Epoch 140, Minibatch cost = 2.011856
# Epoch 140, Validation set cost = 2.019718
# Epoch 141, Minibatch cost = 2.000660
# Epoch 141, Validation set cost = 1.870749
# Epoch 142, Minibatch cost = 1.969634
# Epoch 142, Validation set cost = 1.938314
# Epoch 143, Minibatch cost = 1.976950
# Epoch 143, Validation set cost = 1.906196
# Epoch 144, Minibatch cost = 1.893851
# Epoch 144, Validation set cost = 1.864204
# Epoch 145, Minibatch cost = 2.057369
# Epoch 145, Validation set cost = 1.941831
# Epoch 146, Minibatch cost = 1.876145
# Epoch 146, Validation set cost = 1.901071
# Epoch 147, Minibatch cost = 1.927106
# Epoch 147, Validation set cost = 1.863769
# Epoch 148, Minibatch cost = 1.919401
# Epoch 148, Validation set cost = 1.827423
# Epoch 149, Minibatch cost = 2.011965
# Epoch 149, Validation set cost = 1.842090
# Epoch 150, Minibatch cost = 1.936655
# Epoch 150, Validation set cost = 1.835186
# Epoch 151, Minibatch cost = 1.838932
# Epoch 151, Validation set cost = 1.891404
# Epoch 152, Minibatch cost = 1.917131
# Epoch 152, Validation set cost = 1.869293
# Epoch 153, Minibatch cost = 1.929975
# Epoch 153, Validation set cost = 1.881600
# Epoch 154, Minibatch cost = 1.944750
# Epoch 154, Validation set cost = 1.838539
# Epoch 155, Minibatch cost = 2.011364
# Epoch 155, Validation set cost = 1.826730
# Epoch 156, Minibatch cost = 1.891218
# Epoch 156, Validation set cost = 1.823809
# Epoch 157, Minibatch cost = 1.936020
# Epoch 157, Validation set cost = 1.930739
# Epoch 158, Minibatch cost = 2.002031
# Epoch 158, Validation set cost = 1.920621
# Epoch 159, Minibatch cost = 1.869991
# Epoch 159, Validation set cost = 1.877276
# Epoch 160, Minibatch cost = 1.889287
# Epoch 160, Validation set cost = 1.819554
# Epoch 161, Minibatch cost = 1.951302
# Epoch 161, Validation set cost = 1.868654
# Epoch 162, Minibatch cost = 1.917931
# Epoch 162, Validation set cost = 1.854628
# Epoch 163, Minibatch cost = 1.970687
# Epoch 163, Validation set cost = 1.857040
# Epoch 164, Minibatch cost = 1.966068
# Epoch 164, Validation set cost = 1.832140
# Epoch 165, Minibatch cost = 2.022913
# Epoch 165, Validation set cost = 1.883783
# Epoch 166, Minibatch cost = 1.979076
# Epoch 166, Validation set cost = 1.876326
# Epoch 167, Minibatch cost = 2.011121
# Epoch 167, Validation set cost = 1.851022
# Epoch 168, Minibatch cost = 1.969278
# Epoch 168, Validation set cost = 1.942166
# Epoch 169, Minibatch cost = 1.936089
# Epoch 169, Validation set cost = 1.962192
# Epoch 170, Minibatch cost = 1.981919
# Epoch 170, Validation set cost = 1.998482
# Epoch 171, Minibatch cost = 1.902475
# Epoch 171, Validation set cost = 1.934722
# Epoch 172, Minibatch cost = 1.981049
# Epoch 172, Validation set cost = 1.890884
# Epoch 173, Minibatch cost = 1.968703
# Epoch 173, Validation set cost = 1.959036
# Epoch 174, Minibatch cost = 1.863461
# Epoch 174, Validation set cost = 1.946318
# Epoch 175, Minibatch cost = 1.971051
# Epoch 175, Validation set cost = 1.838009
# Epoch 176, Minibatch cost = 1.847856
# Epoch 176, Validation set cost = 1.812960
# Epoch 177, Minibatch cost = 1.954002
# Epoch 177, Validation set cost = 1.818599
# Epoch 178, Minibatch cost = 1.912827
# Epoch 178, Validation set cost = 1.911745
# Epoch 179, Minibatch cost = 1.955415
# Epoch 179, Validation set cost = 1.875878
# Epoch 180, Minibatch cost = 1.901140
# Epoch 180, Validation set cost = 1.850215
# Epoch 181, Minibatch cost = 1.947831
# Epoch 181, Validation set cost = 1.799841
# Epoch 182, Minibatch cost = 1.836435
# Epoch 182, Validation set cost = 1.821682
# Epoch 183, Minibatch cost = 1.944398
# Epoch 183, Validation set cost = 1.915971
# Epoch 184, Minibatch cost = 1.893291
# Epoch 184, Validation set cost = 1.861527
# Epoch 185, Minibatch cost = 1.916727
# Epoch 185, Validation set cost = 1.812457
# Epoch 186, Minibatch cost = 1.842931
# Epoch 186, Validation set cost = 1.814265
# Epoch 187, Minibatch cost = 1.780290
# Epoch 187, Validation set cost = 1.862586
# Epoch 188, Minibatch cost = 1.894798
# Epoch 188, Validation set cost = 1.804981
# Epoch 189, Minibatch cost = 1.857358
# Epoch 189, Validation set cost = 1.973784
# Epoch 190, Minibatch cost = 2.005563
# Epoch 190, Validation set cost = 1.855522
# Epoch 191, Minibatch cost = 1.990809
# Epoch 191, Validation set cost = 1.855813
# Epoch 192, Minibatch cost = 1.977204
# Epoch 192, Validation set cost = 1.881800
# Epoch 193, Minibatch cost = 1.882554
# Epoch 193, Validation set cost = 1.856850
# Epoch 194, Minibatch cost = 1.946720
# Epoch 194, Validation set cost = 1.858386
# Epoch 195, Minibatch cost = 1.876759
# Epoch 195, Validation set cost = 1.965605
# Epoch 196, Minibatch cost = 1.889109
# Epoch 196, Validation set cost = 1.836164
# Epoch 197, Minibatch cost = 2.116828
# Epoch 197, Validation set cost = 1.941813
# Epoch 198, Minibatch cost = 2.004272
# Epoch 198, Validation set cost = 1.879271
# Epoch 199, Minibatch cost = 1.955684
# Epoch 199, Validation set cost = 1.870003
# Epoch 200, Minibatch cost = 1.953145
# Epoch 200, Validation set cost = 1.854339
# Epoch 201, Minibatch cost = 1.891394
# Epoch 201, Validation set cost = 1.912742
# Epoch 202, Minibatch cost = 1.920963
# Epoch 202, Validation set cost = 1.847456
# Epoch 203, Minibatch cost = 1.953123
# Epoch 203, Validation set cost = 1.828256
# Epoch 204, Minibatch cost = 1.957221
# Epoch 204, Validation set cost = 1.860558
# Epoch 205, Minibatch cost = 1.880529
# Epoch 205, Validation set cost = 1.782359
# Epoch 206, Minibatch cost = 1.949830
# Epoch 206, Validation set cost = 1.887217
# Epoch 207, Minibatch cost = 1.884060
# Epoch 207, Validation set cost = 1.872815
# Epoch 208, Minibatch cost = 1.933974
# Epoch 208, Validation set cost = 1.941652
# Epoch 209, Minibatch cost = 1.913046
# Epoch 209, Validation set cost = 1.908113
# Epoch 210, Minibatch cost = 2.104008
# Epoch 210, Validation set cost = 1.875315
# Epoch 211, Minibatch cost = 2.048585
# Epoch 211, Validation set cost = 1.854334
# Epoch 212, Minibatch cost = 1.907744
# Epoch 212, Validation set cost = 1.835232
# Epoch 213, Minibatch cost = 2.005954
# Epoch 213, Validation set cost = 1.845574
# Epoch 214, Minibatch cost = 1.894999
# Epoch 214, Validation set cost = 1.978693
# Epoch 215, Minibatch cost = 1.939447
# Epoch 215, Validation set cost = 1.885345
# Epoch 216, Minibatch cost = 1.851021
# Epoch 216, Validation set cost = 1.806105
# Epoch 217, Minibatch cost = 1.823242
# Epoch 217, Validation set cost = 1.844348
# Epoch 218, Minibatch cost = 1.927809
# Epoch 218, Validation set cost = 1.859464
# Epoch 219, Minibatch cost = 1.912669
# Epoch 219, Validation set cost = 1.864237
# Epoch 220, Minibatch cost = 1.849514
# Epoch 220, Validation set cost = 1.839289
# Epoch 221, Minibatch cost = 1.949871
# Epoch 221, Validation set cost = 1.811791
# Epoch 222, Minibatch cost = 1.956761
# Epoch 222, Validation set cost = 1.793796
# Epoch 223, Minibatch cost = 1.953434
# Epoch 223, Validation set cost = 1.806291
# Epoch 224, Minibatch cost = 1.852217
# Epoch 224, Validation set cost = 1.790849
# Epoch 225, Minibatch cost = 1.781815
# Epoch 225, Validation set cost = 1.804381
# Epoch 226, Minibatch cost = 1.818760
# Epoch 226, Validation set cost = 1.829159
# Epoch 227, Minibatch cost = 1.851665
# Epoch 227, Validation set cost = 1.866025
# Epoch 228, Minibatch cost = 1.958707
# Epoch 228, Validation set cost = 1.935420
# Epoch 229, Minibatch cost = 1.930215
# Epoch 229, Validation set cost = 1.958360
# Epoch 230, Minibatch cost = 2.010004
# Epoch 230, Validation set cost = 1.865123
# Epoch 231, Minibatch cost = 1.820532
# Epoch 231, Validation set cost = 1.902069
# Epoch 232, Minibatch cost = 1.872255
# Epoch 232, Validation set cost = 1.832677
# Epoch 233, Minibatch cost = 1.933733
# Epoch 233, Validation set cost = 1.926294
# Epoch 234, Minibatch cost = 2.073332
# Epoch 234, Validation set cost = 1.842035
# Epoch 235, Minibatch cost = 1.905975
# Epoch 235, Validation set cost = 1.824375
# Epoch 236, Minibatch cost = 1.980116
# Epoch 236, Validation set cost = 1.873900
# Epoch 237, Minibatch cost = 1.948217
# Epoch 237, Validation set cost = 1.895950
# Epoch 238, Minibatch cost = 1.858679
# Epoch 238, Validation set cost = 1.826209
# Epoch 239, Minibatch cost = 1.933070
# Epoch 239, Validation set cost = 1.848903
# Epoch 240, Minibatch cost = 1.903624
# Epoch 240, Validation set cost = 1.887741
# Epoch 241, Minibatch cost = 1.852963
# Epoch 241, Validation set cost = 1.834158
# Epoch 242, Minibatch cost = 1.872594
# Epoch 242, Validation set cost = 1.861284
# Epoch 243, Minibatch cost = 1.820576
# Epoch 243, Validation set cost = 1.880077
# Epoch 244, Minibatch cost = 2.004831
# Epoch 244, Validation set cost = 1.896489
# Epoch 245, Minibatch cost = 2.034781
# Epoch 245, Validation set cost = 1.855090
# Epoch 246, Minibatch cost = 1.907650
# Epoch 246, Validation set cost = 1.836061
# Epoch 247, Minibatch cost = 1.891531
# Epoch 247, Validation set cost = 1.866448
# Epoch 248, Minibatch cost = 1.918916
# Epoch 248, Validation set cost = 1.836492
# Epoch 249, Minibatch cost = 1.840939
# Epoch 249, Validation set cost = 1.841367
# Epoch 250, Minibatch cost = 1.926773
# Epoch 250, Validation set cost = 1.823908
# Epoch 251, Minibatch cost = 1.908050
# Epoch 251, Validation set cost = 1.797543
# Epoch 252, Minibatch cost = 1.827508
# Epoch 252, Validation set cost = 1.798718
# Epoch 253, Minibatch cost = 1.857375
# Epoch 253, Validation set cost = 1.789319
# Epoch 254, Minibatch cost = 1.959051
# Epoch 254, Validation set cost = 1.840137
# Epoch 255, Minibatch cost = 1.811248
# Epoch 255, Validation set cost = 1.786358
# Epoch 256, Minibatch cost = 1.819414
# Epoch 256, Validation set cost = 1.845962
# Epoch 257, Minibatch cost = 1.936390
# Epoch 257, Validation set cost = 1.859400
# Epoch 258, Minibatch cost = 1.915823
# Epoch 258, Validation set cost = 2.064317
# Epoch 259, Minibatch cost = 1.983288
# Epoch 259, Validation set cost = 2.000507
# Epoch 260, Minibatch cost = 2.008379
# Epoch 260, Validation set cost = 1.870688
# Epoch 261, Minibatch cost = 1.943617
# Epoch 261, Validation set cost = 1.881871
# Epoch 262, Minibatch cost = 1.873291
# Epoch 262, Validation set cost = 1.888114
# Epoch 263, Minibatch cost = 1.936049
# Epoch 263, Validation set cost = 1.840083
# Epoch 264, Minibatch cost = 1.982488
# Epoch 264, Validation set cost = 1.863783
# Epoch 265, Minibatch cost = 1.836887
# Epoch 265, Validation set cost = 1.878353
# Epoch 266, Minibatch cost = 2.007950
# Epoch 266, Validation set cost = 1.802788
# Epoch 267, Minibatch cost = 1.878336
# Epoch 267, Validation set cost = 1.855880
# Epoch 268, Minibatch cost = 1.854554
# Epoch 268, Validation set cost = 1.803690
# Epoch 269, Minibatch cost = 1.953447
# Epoch 269, Validation set cost = 1.902198
# Epoch 270, Minibatch cost = 1.941244
# Epoch 270, Validation set cost = 1.838216
# Epoch 271, Minibatch cost = 1.887572
# Epoch 271, Validation set cost = 1.826185
# Epoch 272, Minibatch cost = 2.022429
# Epoch 272, Validation set cost = 1.867352
# Epoch 273, Minibatch cost = 1.842435
# Epoch 273, Validation set cost = 1.861962
# Epoch 274, Minibatch cost = 1.912358
# Epoch 274, Validation set cost = 1.898267
# Epoch 275, Minibatch cost = 1.870513
# Epoch 275, Validation set cost = 1.885704
# Epoch 276, Minibatch cost = 1.881660
# Epoch 276, Validation set cost = 1.812150
# Epoch 277, Minibatch cost = 1.876358
# Epoch 277, Validation set cost = 1.808784
# Epoch 278, Minibatch cost = 1.862500
# Epoch 278, Validation set cost = 1.908142
# Epoch 279, Minibatch cost = 1.851889
# Epoch 279, Validation set cost = 1.860881
# Epoch 280, Minibatch cost = 1.863634
# Epoch 280, Validation set cost = 1.870581
# Epoch 281, Minibatch cost = 1.920414
# Epoch 281, Validation set cost = 1.810390
# Epoch 282, Minibatch cost = 1.881437
# Epoch 282, Validation set cost = 1.842314
# Epoch 283, Minibatch cost = 1.804732
# Epoch 283, Validation set cost = 1.887740
# Epoch 284, Minibatch cost = 1.820867
# Epoch 284, Validation set cost = 2.169557
# Epoch 285, Minibatch cost = 2.024468
# Epoch 285, Validation set cost = 1.839608
# Epoch 286, Minibatch cost = 1.913880
# Epoch 286, Validation set cost = 1.887309
# Epoch 287, Minibatch cost = 1.917899
# Epoch 287, Validation set cost = 1.867987
# Epoch 288, Minibatch cost = 1.960140
# Epoch 288, Validation set cost = 1.830854
# Epoch 289, Minibatch cost = 1.865814
# Epoch 289, Validation set cost = 1.805620
# Epoch 290, Minibatch cost = 1.874247
# Epoch 290, Validation set cost = 1.845954
# Epoch 291, Minibatch cost = 1.975351
# Epoch 291, Validation set cost = 1.958555
# Epoch 292, Minibatch cost = 1.961708
# Epoch 292, Validation set cost = 1.879242
# Epoch 293, Minibatch cost = 1.925069
# Epoch 293, Validation set cost = 1.868127
# Epoch 294, Minibatch cost = 1.906631
# Epoch 294, Validation set cost = 1.893325
# Epoch 295, Minibatch cost = 1.843039
# Epoch 295, Validation set cost = 1.846056
# Epoch 296, Minibatch cost = 1.804941
# Epoch 296, Validation set cost = 1.875600
# Epoch 297, Minibatch cost = 1.916890
# Epoch 297, Validation set cost = 1.840971
# Epoch 298, Minibatch cost = 1.919125
# Epoch 298, Validation set cost = 1.820500
# Epoch 299, Minibatch cost = 1.862563
# Epoch 299, Validation set cost = 1.846739
# Epoch 300, Minibatch cost = 1.794171
# Epoch 300, Validation set cost = 1.831427
# Epoch 301, Minibatch cost = 1.873482
# Epoch 301, Validation set cost = 1.863461
# Epoch 302, Minibatch cost = 1.853834
# Epoch 302, Validation set cost = 1.831125
# Epoch 303, Minibatch cost = 1.911823
# Epoch 303, Validation set cost = 1.821409
# Epoch 304, Minibatch cost = 1.874919
# Epoch 304, Validation set cost = 2.006710
# Epoch 305, Minibatch cost = 1.966235
# Epoch 305, Validation set cost = 1.801109
# Epoch 306, Minibatch cost = 1.798314
# Epoch 306, Validation set cost = 1.809234
# Epoch 307, Minibatch cost = 1.926626
# Epoch 307, Validation set cost = 1.835851
# Epoch 308, Minibatch cost = 1.902089
# Epoch 308, Validation set cost = 1.860452
# Epoch 309, Minibatch cost = 1.994365
# Epoch 309, Validation set cost = 1.870599
# Epoch 310, Minibatch cost = 1.903940
# Epoch 310, Validation set cost = 1.830459
# Epoch 311, Minibatch cost = 1.802471
# Epoch 311, Validation set cost = 1.850264
# Epoch 312, Minibatch cost = 1.895167
# Epoch 312, Validation set cost = 1.831336
# Epoch 313, Minibatch cost = 1.848701
# Epoch 313, Validation set cost = 1.817520
# Epoch 314, Minibatch cost = 1.929746
# Epoch 314, Validation set cost = 1.846065
# Epoch 315, Minibatch cost = 1.822875
# Epoch 315, Validation set cost = 1.840442
# Epoch 316, Minibatch cost = 1.896912
# Epoch 316, Validation set cost = 1.800183
# Epoch 317, Minibatch cost = 1.840940
# Epoch 317, Validation set cost = 1.830510
# Epoch 318, Minibatch cost = 1.897443
# Epoch 318, Validation set cost = 1.798326
# Epoch 319, Minibatch cost = 1.833544
# Epoch 319, Validation set cost = 1.800307
# Epoch 320, Minibatch cost = 1.918217
# Epoch 320, Validation set cost = 1.952623
# Epoch 321, Minibatch cost = 1.842773
# Epoch 321, Validation set cost = 1.900710
# Epoch 322, Minibatch cost = 1.897183
# Epoch 322, Validation set cost = 1.837775
# Epoch 323, Minibatch cost = 1.886139
# Epoch 323, Validation set cost = 1.922079
# Epoch 324, Minibatch cost = 1.810048
# Epoch 324, Validation set cost = 1.853529
# Epoch 325, Minibatch cost = 1.849692
# Epoch 325, Validation set cost = 1.904541
# Epoch 326, Minibatch cost = 1.818187
# Epoch 326, Validation set cost = 1.788057
# Epoch 327, Minibatch cost = 1.666707
# Epoch 327, Validation set cost = 1.815420
# Epoch 328, Minibatch cost = 1.903931
# Epoch 328, Validation set cost = 1.814184
# Epoch 329, Minibatch cost = 1.842257
# Epoch 329, Validation set cost = 1.873151
# Epoch 330, Minibatch cost = 1.906779
# Epoch 330, Validation set cost = 1.814136
# Epoch 331, Minibatch cost = 1.864014
# Epoch 331, Validation set cost = 1.817164
# Epoch 332, Minibatch cost = 1.814664
# Epoch 332, Validation set cost = 1.858041
# Epoch 333, Minibatch cost = 1.944245
# Epoch 333, Validation set cost = 1.864736
# Epoch 334, Minibatch cost = 1.851483
# Epoch 334, Validation set cost = 1.845969
# Epoch 335, Minibatch cost = 1.823239
# Epoch 335, Validation set cost = 1.976108
# Epoch 336, Minibatch cost = 1.949917
# Epoch 336, Validation set cost = 1.801876
# Epoch 337, Minibatch cost = 1.893169
# Epoch 337, Validation set cost = 1.848414
# Epoch 338, Minibatch cost = 1.887027
# Epoch 338, Validation set cost = 1.759758
# Epoch 339, Minibatch cost = 1.824913
# Epoch 339, Validation set cost = 1.811513
# Epoch 340, Minibatch cost = 1.835018
# Epoch 340, Validation set cost = 1.859187
# Epoch 341, Minibatch cost = 1.860711
# Epoch 341, Validation set cost = 1.832254
# Epoch 342, Minibatch cost = 1.878131
# Epoch 342, Validation set cost = 1.848213
# Epoch 343, Minibatch cost = 1.875494
# Epoch 343, Validation set cost = 1.843981
# Epoch 344, Minibatch cost = 1.910081
# Epoch 344, Validation set cost = 1.812074
# Epoch 345, Minibatch cost = 1.852670
# Epoch 345, Validation set cost = 1.827623
# Epoch 346, Minibatch cost = 1.800862
# Epoch 346, Validation set cost = 1.812767
# Epoch 347, Minibatch cost = 1.897383
# Epoch 347, Validation set cost = 1.845959
# Epoch 348, Minibatch cost = 1.844843
# Epoch 348, Validation set cost = 1.819850
# Epoch 349, Minibatch cost = 1.897292
# Epoch 349, Validation set cost = 1.891156
# Epoch 350, Minibatch cost = 1.932608
# Epoch 350, Validation set cost = 1.806711
# Epoch 351, Minibatch cost = 1.866945
# Epoch 351, Validation set cost = 1.823790
# Epoch 352, Minibatch cost = 1.777263
# Epoch 352, Validation set cost = 1.807620
# Epoch 353, Minibatch cost = 1.925414
# Epoch 353, Validation set cost = 1.858943
# Epoch 354, Minibatch cost = 1.783061
# Epoch 354, Validation set cost = 1.885482
# Epoch 355, Minibatch cost = 1.832760
# Epoch 355, Validation set cost = 1.853999
# Epoch 356, Minibatch cost = 1.783304
# Epoch 356, Validation set cost = 1.853396
# Epoch 357, Minibatch cost = 1.854174
# Epoch 357, Validation set cost = 1.910470
# Epoch 358, Minibatch cost = 1.915230
# Epoch 358, Validation set cost = 1.860784
# Epoch 359, Minibatch cost = 1.938575
# Epoch 359, Validation set cost = 1.806774
# Epoch 360, Minibatch cost = 1.823686
# Epoch 360, Validation set cost = 1.799385
# Epoch 361, Minibatch cost = 1.839088
# Epoch 361, Validation set cost = 1.738668
# Epoch 362, Minibatch cost = 1.912541
# Epoch 362, Validation set cost = 1.760075
# Epoch 363, Minibatch cost = 1.878090
# Epoch 363, Validation set cost = 1.804558
# Epoch 364, Minibatch cost = 1.731565
# Epoch 364, Validation set cost = 1.796456
# Epoch 365, Minibatch cost = 1.790444
# Epoch 365, Validation set cost = 1.771866
# Epoch 366, Minibatch cost = 1.735523
# Epoch 366, Validation set cost = 1.772171
# Epoch 367, Minibatch cost = 1.775519
# Epoch 367, Validation set cost = 1.798383
# Epoch 368, Minibatch cost = 1.860139
# Epoch 368, Validation set cost = 1.805781
# Epoch 369, Minibatch cost = 1.740329
# Epoch 369, Validation set cost = 1.776792
# Epoch 370, Minibatch cost = 1.842813
# Epoch 370, Validation set cost = 1.753258
# Epoch 371, Minibatch cost = 1.870918
# Epoch 371, Validation set cost = 1.792481
# Epoch 372, Minibatch cost = 1.890961
# Epoch 372, Validation set cost = 2.045340
# Epoch 373, Minibatch cost = 1.833489
# Epoch 373, Validation set cost = 1.853593
# Epoch 374, Minibatch cost = 1.926560
# Epoch 374, Validation set cost = 1.875244
# Epoch 375, Minibatch cost = 1.876908
# Epoch 375, Validation set cost = 1.817905
# Epoch 376, Minibatch cost = 1.897764
# Epoch 376, Validation set cost = 1.885170
# Epoch 377, Minibatch cost = 1.885306
# Epoch 377, Validation set cost = 1.799993
# Epoch 378, Minibatch cost = 1.926268
# Epoch 378, Validation set cost = 1.814142
# Epoch 379, Minibatch cost = 1.897893
# Epoch 379, Validation set cost = 1.787834
# Epoch 380, Minibatch cost = 1.815485
# Epoch 380, Validation set cost = 1.814560
# Epoch 381, Minibatch cost = 1.816071
# Epoch 381, Validation set cost = 1.745612
# Epoch 382, Minibatch cost = 1.882648
# Epoch 382, Validation set cost = 1.816194
# Epoch 383, Minibatch cost = 1.841623
# Epoch 383, Validation set cost = 1.834752
# Epoch 384, Minibatch cost = 1.869337
# Epoch 384, Validation set cost = 1.831400
# Epoch 385, Minibatch cost = 1.893138
# Epoch 385, Validation set cost = 1.870967
# Epoch 386, Minibatch cost = 1.838666
# Epoch 386, Validation set cost = 1.885868
# Epoch 387, Minibatch cost = 1.832967
# Epoch 387, Validation set cost = 1.865745
# Epoch 388, Minibatch cost = 1.863720
# Epoch 388, Validation set cost = 1.780375
# Epoch 389, Minibatch cost = 1.855993
# Epoch 389, Validation set cost = 1.783931
# Epoch 390, Minibatch cost = 1.803725
# Epoch 390, Validation set cost = 1.822748
# Epoch 391, Minibatch cost = 1.914488
# Epoch 391, Validation set cost = 1.837353
# Epoch 392, Minibatch cost = 1.831123
# Epoch 392, Validation set cost = 1.772121
# Epoch 393, Minibatch cost = 1.803988
# Epoch 393, Validation set cost = 1.818535
# Epoch 394, Minibatch cost = 1.844243
# Epoch 394, Validation set cost = 1.872120
# Epoch 395, Minibatch cost = 1.757009
# Epoch 395, Validation set cost = 1.890939
# Epoch 396, Minibatch cost = 1.876647
# Epoch 396, Validation set cost = 1.876009
# Epoch 397, Minibatch cost = 1.814788
# Epoch 397, Validation set cost = 1.824754
# Epoch 398, Minibatch cost = 1.757396
# Epoch 398, Validation set cost = 1.835799
# Epoch 399, Minibatch cost = 1.939021
# Epoch 399, Validation set cost = 1.805545
# Epoch 400, Minibatch cost = 1.901014
# Epoch 400, Validation set cost = 1.803081
# Epoch 401, Minibatch cost = 1.751520
# Epoch 401, Validation set cost = 1.803796
# Epoch 402, Minibatch cost = 1.903832
# Epoch 402, Validation set cost = 1.834498
# Epoch 403, Minibatch cost = 1.856213
# Epoch 403, Validation set cost = 1.830951
# Epoch 404, Minibatch cost = 2.000564
# Epoch 404, Validation set cost = 1.759310
# Epoch 405, Minibatch cost = 1.842062
# Epoch 405, Validation set cost = 1.971574
# Epoch 406, Minibatch cost = 1.815239
# Epoch 406, Validation set cost = 1.918222
# Epoch 407, Minibatch cost = 1.904934
# Epoch 407, Validation set cost = 1.827587
# Epoch 408, Minibatch cost = 1.793032
# Epoch 408, Validation set cost = 1.861907
# Epoch 409, Minibatch cost = 1.860359
# Epoch 409, Validation set cost = 1.801214
# Epoch 410, Minibatch cost = 1.881258
# Epoch 410, Validation set cost = 1.805440
# Epoch 411, Minibatch cost = 1.814067
# Epoch 411, Validation set cost = 1.839644
# Epoch 412, Minibatch cost = 1.816377
# Epoch 412, Validation set cost = 1.844861
# Epoch 413, Minibatch cost = 1.798241
# Epoch 413, Validation set cost = 1.803577
# Epoch 414, Minibatch cost = 1.789093
# Epoch 414, Validation set cost = 1.864711
# Epoch 415, Minibatch cost = 1.924513
# Epoch 415, Validation set cost = 1.882854
# Epoch 416, Minibatch cost = 1.806583
# Epoch 416, Validation set cost = 1.887561
# Epoch 417, Minibatch cost = 1.893978
# Epoch 417, Validation set cost = 1.963481
# Epoch 418, Minibatch cost = 1.826138
# Epoch 418, Validation set cost = 1.923891
# Epoch 419, Minibatch cost = 1.810652
# Epoch 419, Validation set cost = 1.897769
# Epoch 420, Minibatch cost = 1.838329
# Epoch 420, Validation set cost = 1.923356
# Epoch 421, Minibatch cost = 1.899156
# Epoch 421, Validation set cost = 1.862196
# Epoch 422, Minibatch cost = 1.831828
# Epoch 422, Validation set cost = 1.826672
# Epoch 423, Minibatch cost = 1.878706
# Epoch 423, Validation set cost = 1.844734
# Epoch 424, Minibatch cost = 1.890221
# Epoch 424, Validation set cost = 1.862178
# Epoch 425, Minibatch cost = 1.873779
# Epoch 425, Validation set cost = 1.814324
# Epoch 426, Minibatch cost = 1.788534
# Epoch 426, Validation set cost = 1.907130
# Epoch 427, Minibatch cost = 1.827894
# Epoch 427, Validation set cost = 1.861643
# Epoch 428, Minibatch cost = 1.769193
# Epoch 428, Validation set cost = 1.882140
# Epoch 429, Minibatch cost = 1.847780
# Epoch 429, Validation set cost = 1.838526
# Epoch 430, Minibatch cost = 1.807049
# Epoch 430, Validation set cost = 1.822128
# Epoch 431, Minibatch cost = 1.876791
# Epoch 431, Validation set cost = 1.826889
# Epoch 432, Minibatch cost = 1.844408
# Epoch 432, Validation set cost = 1.954437
# Epoch 433, Minibatch cost = 1.866133
# Epoch 433, Validation set cost = 1.833103
# Epoch 434, Minibatch cost = 1.859178
# Epoch 434, Validation set cost = 1.836117
# Epoch 435, Minibatch cost = 1.871944
# Epoch 435, Validation set cost = 1.823035
# Epoch 436, Minibatch cost = 1.786376
# Epoch 436, Validation set cost = 1.815514
# Epoch 437, Minibatch cost = 1.961021
# Epoch 437, Validation set cost = 1.858574
# Epoch 438, Minibatch cost = 1.839106
# Epoch 438, Validation set cost = 1.795607
# Epoch 439, Minibatch cost = 1.857183
# Epoch 439, Validation set cost = 1.852137
# Epoch 440, Minibatch cost = 1.868063
# Epoch 440, Validation set cost = 1.859074
# Epoch 441, Minibatch cost = 1.838978
# Epoch 441, Validation set cost = 1.891632
# Epoch 442, Minibatch cost = 1.852280
# Epoch 442, Validation set cost = 1.797821
# Epoch 443, Minibatch cost = 1.730982
# Epoch 443, Validation set cost = 1.760966
# Epoch 444, Minibatch cost = 1.861248
# Epoch 444, Validation set cost = 1.811245
# Epoch 445, Minibatch cost = 1.880942
# Epoch 445, Validation set cost = 1.824117
# Epoch 446, Minibatch cost = 1.829346
# Epoch 446, Validation set cost = 1.779906
# Epoch 447, Minibatch cost = 1.799996
# Epoch 447, Validation set cost = 1.819967
# Epoch 448, Minibatch cost = 1.802217
# Epoch 448, Validation set cost = 1.814460
# Epoch 449, Minibatch cost = 1.866635
# Epoch 449, Validation set cost = 1.786080
# Epoch 450, Minibatch cost = 1.756070
# Epoch 450, Validation set cost = 1.858693
# Epoch 451, Minibatch cost = 1.884250
# Epoch 451, Validation set cost = 1.757347
# Epoch 452, Minibatch cost = 1.902551
# Epoch 452, Validation set cost = 1.796946
# Epoch 453, Minibatch cost = 1.912682
# Epoch 453, Validation set cost = 1.787154
# Epoch 454, Minibatch cost = 1.880918
# Epoch 454, Validation set cost = 1.831539
# Epoch 455, Minibatch cost = 1.851972
# Epoch 455, Validation set cost = 1.846099
# Epoch 456, Minibatch cost = 1.794214
# Epoch 456, Validation set cost = 1.863444
# Epoch 457, Minibatch cost = 1.797672
# Epoch 457, Validation set cost = 1.812237
# Epoch 458, Minibatch cost = 1.907508
# Epoch 458, Validation set cost = 1.925307
# Epoch 459, Minibatch cost = 1.876755
# Epoch 459, Validation set cost = 1.842191
# Epoch 460, Minibatch cost = 1.830179
# Epoch 460, Validation set cost = 1.799839
# Epoch 461, Minibatch cost = 1.964242
# Epoch 461, Validation set cost = 1.822001
# Epoch 462, Minibatch cost = 1.775458
# Epoch 462, Validation set cost = 1.782307
# Epoch 463, Minibatch cost = 1.787418
# Epoch 463, Validation set cost = 1.807904
# Epoch 464, Minibatch cost = 1.883063
# Epoch 464, Validation set cost = 1.740989
# Epoch 465, Minibatch cost = 1.843768
# Epoch 465, Validation set cost = 1.835959
# Epoch 466, Minibatch cost = 1.775549
# Epoch 466, Validation set cost = 1.841951
# Epoch 467, Minibatch cost = 1.956279
# Epoch 467, Validation set cost = 1.810126
# Epoch 468, Minibatch cost = 1.803168
# Epoch 468, Validation set cost = 1.838211
# Epoch 469, Minibatch cost = 1.866518
# Epoch 469, Validation set cost = 1.857199
# Epoch 470, Minibatch cost = 1.871611
# Epoch 470, Validation set cost = 1.786354
# Epoch 471, Minibatch cost = 1.783159
# Epoch 471, Validation set cost = 1.850254
# Epoch 472, Minibatch cost = 1.859777
# Epoch 472, Validation set cost = 1.807745
# Epoch 473, Minibatch cost = 1.868178
# Epoch 473, Validation set cost = 1.799642
# Epoch 474, Minibatch cost = 1.845729
# Epoch 474, Validation set cost = 1.809862
# Epoch 475, Minibatch cost = 1.896041
# Epoch 475, Validation set cost = 1.761987
# Epoch 476, Minibatch cost = 1.871845
# Epoch 476, Validation set cost = 1.744081
# Epoch 477, Minibatch cost = 1.767511
# Epoch 477, Validation set cost = 1.746837
# Epoch 478, Minibatch cost = 1.854371
# Epoch 478, Validation set cost = 1.830663
# Epoch 479, Minibatch cost = 1.818363
# Epoch 479, Validation set cost = 1.783769
# Epoch 480, Minibatch cost = 1.816215
# Epoch 480, Validation set cost = 1.771587
# Epoch 481, Minibatch cost = 1.832577
# Epoch 481, Validation set cost = 1.817794
# Epoch 482, Minibatch cost = 1.879759
# Epoch 482, Validation set cost = 1.852333
# Epoch 483, Minibatch cost = 1.804013
# Epoch 483, Validation set cost = 1.781886
# Epoch 484, Minibatch cost = 1.828039
# Epoch 484, Validation set cost = 1.774973
# Epoch 485, Minibatch cost = 1.907206
# Epoch 485, Validation set cost = 1.792237
# Epoch 486, Minibatch cost = 1.954543
# Epoch 486, Validation set cost = 1.844996
# Epoch 487, Minibatch cost = 1.811451
# Epoch 487, Validation set cost = 1.821333
# Epoch 488, Minibatch cost = 1.752192
# Epoch 488, Validation set cost = 1.812951
# Epoch 489, Minibatch cost = 1.892304
# Epoch 489, Validation set cost = 1.801432
# Epoch 490, Minibatch cost = 1.920816
# Epoch 490, Validation set cost = 1.808727
# Epoch 491, Minibatch cost = 1.753170
# Epoch 491, Validation set cost = 1.900101
# Epoch 492, Minibatch cost = 1.860130
# Epoch 492, Validation set cost = 1.923500
# Epoch 493, Minibatch cost = 1.830685
# Epoch 493, Validation set cost = 1.848289
# Epoch 494, Minibatch cost = 1.866942
# Epoch 494, Validation set cost = 1.818901
# Epoch 495, Minibatch cost = 1.841438
# Epoch 495, Validation set cost = 1.786577
# Epoch 496, Minibatch cost = 1.792736
# Epoch 496, Validation set cost = 1.770295
# Epoch 497, Minibatch cost = 1.786030
# Epoch 497, Validation set cost = 1.778392
# Epoch 498, Minibatch cost = 1.819580
# Epoch 498, Validation set cost = 1.763282
# Epoch 499, Minibatch cost = 1.852998
# Epoch 499, Validation set cost = 1.795367
# Model saved in file: ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
#
# Current validation performance:
#
# Displaying graph for dataseries 0:
# Displaying graph for dataseries 1:

# %%
 filename = 'predict_window_50-2.csv'
seed = x_train[101]
predictions = generate_prediction(seed, 5000, restore_path=model_path, progress_counter=20)
np.savetxt(filename, predictions, delimiter=",")
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Generating sequence.
# Generated 0 of 5000 data points.
# Generated 250 of 5000 data points.
# Generated 500 of 5000 data points.
# Generated 750 of 5000 data points.
# Generated 1000 of 5000 data points.
# Generated 1250 of 5000 data points.
# Generated 1500 of 5000 data points.
# Generated 1750 of 5000 data points.
# Generated 2000 of 5000 data points.
# Generated 2250 of 5000 data points.
# Generated 2500 of 5000 data points.
# Generated 2750 of 5000 data points.
# Generated 3000 of 5000 data points.
# Generated 3250 of 5000 data points.
# Generated 3500 of 5000 data points.
# Generated 3750 of 5000 data points.
# Generated 4000 of 5000 data points.
# Generated 4250 of 5000 data points.
# Generated 4500 of 5000 data points.
# Generated 4750 of 5000 data points.
# Done!

# %%
train_model(n_epochs=500,display_step=10,learning_rate=0.0001, restore_from_save=True)
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Resuming training.
# Epoch 0, Minibatch cost = 1.891643
# Epoch 0, Validation set cost = 1.745668
# Epoch 1, Minibatch cost = 1.849551
# Epoch 1, Validation set cost = 1.764434
# Epoch 2, Minibatch cost = 1.766685
# Epoch 2, Validation set cost = 1.755637
# Epoch 3, Minibatch cost = 1.800393
# Epoch 3, Validation set cost = 1.776155
# Epoch 4, Minibatch cost = 1.849827
# Epoch 4, Validation set cost = 1.821070
# Epoch 5, Minibatch cost = 1.831081
# Epoch 5, Validation set cost = 1.825677
# Epoch 6, Minibatch cost = 1.889863
# Epoch 6, Validation set cost = 2.022732
# Epoch 7, Minibatch cost = 1.768138
# Epoch 7, Validation set cost = 1.966591
# Epoch 8, Minibatch cost = 1.963391
# Epoch 8, Validation set cost = 1.808799
# Epoch 9, Minibatch cost = 1.828434
# Epoch 9, Validation set cost = 1.791394
# Epoch 10, Minibatch cost = 1.787078
# Epoch 10, Validation set cost = 1.770567
# Epoch 11, Minibatch cost = 1.838652
# Epoch 11, Validation set cost = 1.797313
# Epoch 12, Minibatch cost = 1.869601
# Epoch 12, Validation set cost = 1.761113
# Epoch 13, Minibatch cost = 1.834929
# Epoch 13, Validation set cost = 1.782340
# Epoch 14, Minibatch cost = 1.814479
# Epoch 14, Validation set cost = 1.818508
# Epoch 15, Minibatch cost = 1.742377
# Epoch 15, Validation set cost = 1.779000
# Epoch 16, Minibatch cost = 1.856586
# Epoch 16, Validation set cost = 1.828791
# Epoch 17, Minibatch cost = 1.813948
# Epoch 17, Validation set cost = 1.853642
# Epoch 18, Minibatch cost = 1.797083
# Epoch 18, Validation set cost = 1.762511
# Epoch 19, Minibatch cost = 1.871431
# Epoch 19, Validation set cost = 1.796078
# Epoch 20, Minibatch cost = 1.946932
# Epoch 20, Validation set cost = 1.771537
# Epoch 21, Minibatch cost = 1.768516
# Epoch 21, Validation set cost = 1.799930
# Epoch 22, Minibatch cost = 1.866701
# Epoch 22, Validation set cost = 1.799643
# Epoch 23, Minibatch cost = 1.829026
# Epoch 23, Validation set cost = 1.852539
# Epoch 24, Minibatch cost = 1.719339
# Epoch 24, Validation set cost = 1.818229
# Epoch 25, Minibatch cost = 1.819263
# Epoch 25, Validation set cost = 1.853920
# Epoch 26, Minibatch cost = 1.876415
# Epoch 26, Validation set cost = 1.880825
# Epoch 27, Minibatch cost = 1.854754
# Epoch 27, Validation set cost = 1.807334
# Epoch 28, Minibatch cost = 1.834823
# Epoch 28, Validation set cost = 1.863931
# Epoch 29, Minibatch cost = 1.817955
# Epoch 29, Validation set cost = 1.799995
# Epoch 30, Minibatch cost = 1.824618
# Epoch 30, Validation set cost = 1.806185
# Epoch 31, Minibatch cost = 1.876492
# Epoch 31, Validation set cost = 1.870315
# Epoch 32, Minibatch cost = 1.769815
# Epoch 32, Validation set cost = 1.794589
# Epoch 33, Minibatch cost = 1.802087
# Epoch 33, Validation set cost = 1.783160
# Epoch 34, Minibatch cost = 1.752224
# Epoch 34, Validation set cost = 1.794950
# Epoch 35, Minibatch cost = 1.806374
# Epoch 35, Validation set cost = 1.790130
# Epoch 36, Minibatch cost = 1.816463
# Epoch 36, Validation set cost = 1.805684
# Epoch 37, Minibatch cost = 1.806255
# Epoch 37, Validation set cost = 1.796075
# Epoch 38, Minibatch cost = 1.803221
# Epoch 38, Validation set cost = 1.814186
# Epoch 39, Minibatch cost = 1.823930
# Epoch 39, Validation set cost = 1.767636
# Epoch 40, Minibatch cost = 1.865367
# Epoch 40, Validation set cost = 1.772799
# Epoch 41, Minibatch cost = 1.820233
# Epoch 41, Validation set cost = 1.728667
# Epoch 42, Minibatch cost = 1.793821
# Epoch 42, Validation set cost = 1.761030
# Epoch 43, Minibatch cost = 1.717397
# Epoch 43, Validation set cost = 1.754265
# Epoch 44, Minibatch cost = 1.780541
# Epoch 44, Validation set cost = 1.795256
# Epoch 45, Minibatch cost = 1.819494
# Epoch 45, Validation set cost = 1.866097
# Epoch 46, Minibatch cost = 1.756395
# Epoch 46, Validation set cost = 1.822214
# Epoch 47, Minibatch cost = 1.795645
# Epoch 47, Validation set cost = 1.812789
# Epoch 48, Minibatch cost = 1.826102
# Epoch 48, Validation set cost = 1.834883
# Epoch 49, Minibatch cost = 1.735040
# Epoch 49, Validation set cost = 1.809009
# Epoch 50, Minibatch cost = 1.782280
# Epoch 50, Validation set cost = 1.791320
# Epoch 51, Minibatch cost = 1.818756
# Epoch 51, Validation set cost = 1.849674
# Epoch 52, Minibatch cost = 1.770564
# Epoch 52, Validation set cost = 1.772838
# Epoch 53, Minibatch cost = 1.817682
# Epoch 53, Validation set cost = 1.862409
# Epoch 54, Minibatch cost = 1.874994
# Epoch 54, Validation set cost = 1.828398
# Epoch 55, Minibatch cost = 1.869457
# Epoch 55, Validation set cost = 1.853840
# Epoch 56, Minibatch cost = 1.776496
# Epoch 56, Validation set cost = 1.891419
# Epoch 57, Minibatch cost = 1.882746
# Epoch 57, Validation set cost = 1.821035
# Epoch 58, Minibatch cost = 1.887094
# Epoch 58, Validation set cost = 1.778231
# Epoch 59, Minibatch cost = 1.783597
# Epoch 59, Validation set cost = 1.849038
# Epoch 60, Minibatch cost = 1.802562
# Epoch 60, Validation set cost = 1.790074
# Epoch 61, Minibatch cost = 1.800087
# Epoch 61, Validation set cost = 1.770798
# Epoch 62, Minibatch cost = 1.806468
# Epoch 62, Validation set cost = 1.829891
# Epoch 63, Minibatch cost = 1.841525
# Epoch 63, Validation set cost = 1.822033
# Epoch 64, Minibatch cost = 1.880751
# Epoch 64, Validation set cost = 1.759346
# Epoch 65, Minibatch cost = 1.759591
# Epoch 65, Validation set cost = 1.738209
# Epoch 66, Minibatch cost = 1.800640
# Epoch 66, Validation set cost = 1.828427
# Epoch 67, Minibatch cost = 1.758090
# Epoch 67, Validation set cost = 1.815441
# Epoch 68, Minibatch cost = 1.802173
# Epoch 68, Validation set cost = 1.727120
# Epoch 69, Minibatch cost = 1.848711
# Epoch 69, Validation set cost = 1.757848
# Epoch 70, Minibatch cost = 1.831670
# Epoch 70, Validation set cost = 1.832176
# Epoch 71, Minibatch cost = 1.776096
# Epoch 71, Validation set cost = 1.829848
# Epoch 72, Minibatch cost = 1.876306
# Epoch 72, Validation set cost = 1.918704
# Epoch 73, Minibatch cost = 1.852259
# Epoch 73, Validation set cost = 1.769727
# Epoch 74, Minibatch cost = 1.796663
# Epoch 74, Validation set cost = 1.826823
# Epoch 75, Minibatch cost = 1.785330
# Epoch 75, Validation set cost = 1.799445
# Epoch 76, Minibatch cost = 1.843183
# Epoch 76, Validation set cost = 1.818714
# Epoch 77, Minibatch cost = 1.806714
# Epoch 77, Validation set cost = 1.764830
# Epoch 78, Minibatch cost = 1.802907
# Epoch 78, Validation set cost = 1.719600
# Epoch 79, Minibatch cost = 1.784802
# Epoch 79, Validation set cost = 1.833700
# Epoch 80, Minibatch cost = 1.799601
# Epoch 80, Validation set cost = 1.791981
# Epoch 81, Minibatch cost = 1.861756
# Epoch 81, Validation set cost = 1.833127
# Epoch 82, Minibatch cost = 1.855501
# Epoch 82, Validation set cost = 1.829140
# Epoch 83, Minibatch cost = 1.830851
# Epoch 83, Validation set cost = 1.867673
# Epoch 84, Minibatch cost = 1.923454
# Epoch 84, Validation set cost = 1.823829
# Epoch 85, Minibatch cost = 1.783856
# Epoch 85, Validation set cost = 1.770802
# Epoch 86, Minibatch cost = 1.904734
# Epoch 86, Validation set cost = 1.785000
# Epoch 87, Minibatch cost = 1.823967
# Epoch 87, Validation set cost = 1.788552
# Epoch 88, Minibatch cost = 1.793318
# Epoch 88, Validation set cost = 1.775189
# Epoch 89, Minibatch cost = 1.821350
# Epoch 89, Validation set cost = 1.848780
# Epoch 90, Minibatch cost = 1.870082
# Epoch 90, Validation set cost = 1.786615
# Epoch 91, Minibatch cost = 1.741765
# Epoch 91, Validation set cost = 1.763119
# Epoch 92, Minibatch cost = 1.749316
# Epoch 92, Validation set cost = 1.772538
# Epoch 93, Minibatch cost = 1.807771
# Epoch 93, Validation set cost = 1.738924
# Epoch 94, Minibatch cost = 1.776541
# Epoch 94, Validation set cost = 1.808918
# Epoch 95, Minibatch cost = 1.906149
# Epoch 95, Validation set cost = 1.911937
# Epoch 96, Minibatch cost = 1.935819
# Epoch 96, Validation set cost = 1.755474
# Epoch 97, Minibatch cost = 1.748641
# Epoch 97, Validation set cost = 1.726750
# Epoch 98, Minibatch cost = 1.860090
# Epoch 98, Validation set cost = 1.791932
# Epoch 99, Minibatch cost = 1.848019
# Epoch 99, Validation set cost = 1.834477
# Epoch 100, Minibatch cost = 1.839205
# Epoch 100, Validation set cost = 1.920664
# Epoch 101, Minibatch cost = 1.785597
# Epoch 101, Validation set cost = 1.939106
# Epoch 102, Minibatch cost = 1.861085
# Epoch 102, Validation set cost = 1.789614
# Epoch 103, Minibatch cost = 1.761977
# Epoch 103, Validation set cost = 1.782268
# Epoch 104, Minibatch cost = 1.784105
# Epoch 104, Validation set cost = 1.811816
# Epoch 105, Minibatch cost = 1.788108
# Epoch 105, Validation set cost = 1.791949
# Epoch 106, Minibatch cost = 1.724740
# Epoch 106, Validation set cost = 1.794127
# Epoch 107, Minibatch cost = 1.764246
# Epoch 107, Validation set cost = 1.807689
# Epoch 108, Minibatch cost = 1.832020
# Epoch 108, Validation set cost = 1.839689
# Epoch 109, Minibatch cost = 1.789421
# Epoch 109, Validation set cost = 1.820769
# Epoch 110, Minibatch cost = 1.756255
# Epoch 110, Validation set cost = 1.837330
# Epoch 111, Minibatch cost = 1.819005
# Epoch 111, Validation set cost = 1.748671
# Epoch 112, Minibatch cost = 1.757247
# Epoch 112, Validation set cost = 1.758997
# Epoch 113, Minibatch cost = 1.850715
# Epoch 113, Validation set cost = 1.793059
# Epoch 114, Minibatch cost = 1.834054
# Epoch 114, Validation set cost = 1.820650
# Epoch 115, Minibatch cost = 1.781303
# Epoch 115, Validation set cost = 1.831848
# Epoch 116, Minibatch cost = 1.907720
# Epoch 116, Validation set cost = 1.791349
# Epoch 117, Minibatch cost = 1.825028
# Epoch 117, Validation set cost = 1.859970
# Epoch 118, Minibatch cost = 1.828429
# Epoch 118, Validation set cost = 1.845106
# Epoch 119, Minibatch cost = 1.858223
# Epoch 119, Validation set cost = 1.850970
# Epoch 120, Minibatch cost = 1.828702
# Epoch 120, Validation set cost = 1.820863
# Epoch 121, Minibatch cost = 1.806388
# Epoch 121, Validation set cost = 1.904698
# Epoch 122, Minibatch cost = 1.724601
# Epoch 122, Validation set cost = 1.839582
# Epoch 123, Minibatch cost = 1.747314
# Epoch 123, Validation set cost = 1.879970
# Epoch 124, Minibatch cost = 1.845254
# Epoch 124, Validation set cost = 1.776829
# Epoch 125, Minibatch cost = 1.882070
# Epoch 125, Validation set cost = 1.843949
# Epoch 126, Minibatch cost = 1.808965
# Epoch 126, Validation set cost = 1.803694
# Epoch 127, Minibatch cost = 1.872125
# Epoch 127, Validation set cost = 1.869978
# Epoch 128, Minibatch cost = 1.818441
# Epoch 128, Validation set cost = 1.791429
# Epoch 129, Minibatch cost = 1.787075
# Epoch 129, Validation set cost = 1.752769
# Epoch 130, Minibatch cost = 1.811326
# Epoch 130, Validation set cost = 1.817379
# Epoch 131, Minibatch cost = 1.777844
# Epoch 131, Validation set cost = 1.801303
# Epoch 132, Minibatch cost = 1.753397
# Epoch 132, Validation set cost = 1.822161
# Epoch 133, Minibatch cost = 1.772167
# Epoch 133, Validation set cost = 1.793264
# Epoch 134, Minibatch cost = 1.712542
# Epoch 134, Validation set cost = 1.877537
# Epoch 135, Minibatch cost = 1.876266
# Epoch 135, Validation set cost = 2.003364
# Epoch 136, Minibatch cost = 1.865541
# Epoch 136, Validation set cost = 1.947789
# Epoch 137, Minibatch cost = 1.865077
# Epoch 137, Validation set cost = 1.866525
# Epoch 138, Minibatch cost = 1.876917
# Epoch 138, Validation set cost = 1.878113
# Epoch 139, Minibatch cost = 1.796182
# Epoch 139, Validation set cost = 1.803541
# Epoch 140, Minibatch cost = 1.874869
# Epoch 140, Validation set cost = 1.778850
# Epoch 141, Minibatch cost = 1.766634
# Epoch 141, Validation set cost = 1.748399
# Epoch 142, Minibatch cost = 1.702633
# Epoch 142, Validation set cost = 1.855691
# Epoch 143, Minibatch cost = 1.842109
# Epoch 143, Validation set cost = 1.797270
# Epoch 144, Minibatch cost = 1.810426
# Epoch 144, Validation set cost = 1.875927
# Epoch 145, Minibatch cost = 1.847574
# Epoch 145, Validation set cost = 1.837704
# Epoch 146, Minibatch cost = 1.816339
# Epoch 146, Validation set cost = 1.806996
# Epoch 147, Minibatch cost = 1.809430
# Epoch 147, Validation set cost = 1.782510
# Epoch 148, Minibatch cost = 1.820059
# Epoch 148, Validation set cost = 1.798628
# Epoch 149, Minibatch cost = 1.813423
# Epoch 149, Validation set cost = 1.804429
# Epoch 150, Minibatch cost = 1.795763
# Epoch 150, Validation set cost = 1.848833
# Epoch 151, Minibatch cost = 1.743084
# Epoch 151, Validation set cost = 1.754997
# Epoch 152, Minibatch cost = 1.751027
# Epoch 152, Validation set cost = 1.805132
# Epoch 153, Minibatch cost = 1.814091
# Epoch 153, Validation set cost = 1.858134
# Epoch 154, Minibatch cost = 1.840576
# Epoch 154, Validation set cost = 1.792980
# Epoch 155, Minibatch cost = 1.731632
# Epoch 155, Validation set cost = 1.760745
# Epoch 156, Minibatch cost = 1.817272
# Epoch 156, Validation set cost = 1.786415
# Epoch 157, Minibatch cost = 1.795192
# Epoch 157, Validation set cost = 1.773237
# Epoch 158, Minibatch cost = 1.703696
# Epoch 158, Validation set cost = 1.784096
# Epoch 159, Minibatch cost = 1.737749
# Epoch 159, Validation set cost = 1.832410
# Epoch 160, Minibatch cost = 1.770416
# Epoch 160, Validation set cost = 1.903289
# Epoch 161, Minibatch cost = 1.773452
# Epoch 161, Validation set cost = 1.822597
# Epoch 162, Minibatch cost = 1.749018
# Epoch 162, Validation set cost = 1.798612
# Epoch 163, Minibatch cost = 1.771273
# Epoch 163, Validation set cost = 1.826790
# Epoch 164, Minibatch cost = 1.818017
# Epoch 164, Validation set cost = 1.776026
# Epoch 165, Minibatch cost = 1.877310
# Epoch 165, Validation set cost = 1.848159
# Epoch 166, Minibatch cost = 1.831827
# Epoch 166, Validation set cost = 1.766098
# Epoch 167, Minibatch cost = 1.727333
# Epoch 167, Validation set cost = 1.839634
# Epoch 168, Minibatch cost = 1.765439
# Epoch 168, Validation set cost = 1.880753
# Epoch 169, Minibatch cost = 1.873791
# Epoch 169, Validation set cost = 1.769322
# Epoch 170, Minibatch cost = 1.773611
# Epoch 170, Validation set cost = 1.782025
# Epoch 171, Minibatch cost = 1.836657
# Epoch 171, Validation set cost = 1.755221
# Epoch 172, Minibatch cost = 1.920666
# Epoch 172, Validation set cost = 1.816887
# Epoch 173, Minibatch cost = 1.815919
# Epoch 173, Validation set cost = 1.758755
# Epoch 174, Minibatch cost = 1.790924
# Epoch 174, Validation set cost = 1.736152
# Epoch 175, Minibatch cost = 1.811584
# Epoch 175, Validation set cost = 1.737274
# Epoch 176, Minibatch cost = 1.916670
# Epoch 176, Validation set cost = 1.803614
# Epoch 177, Minibatch cost = 1.824798
# Epoch 177, Validation set cost = 1.753596
# Epoch 178, Minibatch cost = 1.816934
# Epoch 178, Validation set cost = 1.821095
# Epoch 179, Minibatch cost = 1.830824
# Epoch 179, Validation set cost = 1.772143
# Epoch 180, Minibatch cost = 1.784302
# Epoch 180, Validation set cost = 1.809848
# Epoch 181, Minibatch cost = 1.750586
# Epoch 181, Validation set cost = 1.816849
# Epoch 182, Minibatch cost = 1.819264
# Epoch 182, Validation set cost = 1.809254
# Epoch 183, Minibatch cost = 1.812130
# Epoch 183, Validation set cost = 1.933633
# Epoch 184, Minibatch cost = 1.852100
# Epoch 184, Validation set cost = 1.847655
# Epoch 185, Minibatch cost = 1.776799
# Epoch 185, Validation set cost = 1.822962
# Epoch 186, Minibatch cost = 1.869638
# Epoch 186, Validation set cost = 1.788990
# Epoch 187, Minibatch cost = 1.756594
# Epoch 187, Validation set cost = 1.755504
# Epoch 188, Minibatch cost = 1.816811
# Epoch 188, Validation set cost = 1.816020
# Epoch 189, Minibatch cost = 1.742983
# Epoch 189, Validation set cost = 1.790256
# Epoch 190, Minibatch cost = 1.776486
# Epoch 190, Validation set cost = 1.771659
# Epoch 191, Minibatch cost = 1.763863
# Epoch 191, Validation set cost = 1.766844
# Epoch 192, Minibatch cost = 1.742034
# Epoch 192, Validation set cost = 1.728927
# Epoch 193, Minibatch cost = 1.766606
# Epoch 193, Validation set cost = 1.764891
# Epoch 194, Minibatch cost = 1.791833
# Epoch 194, Validation set cost = 1.779992
# Epoch 195, Minibatch cost = 1.673352
# Epoch 195, Validation set cost = 1.768288
# Epoch 196, Minibatch cost = 1.753605
# Epoch 196, Validation set cost = 1.785977
# Epoch 197, Minibatch cost = 1.819257
# Epoch 197, Validation set cost = 1.761483
# Epoch 198, Minibatch cost = 1.729656
# Epoch 198, Validation set cost = 1.781068
# Epoch 199, Minibatch cost = 1.754679
# Epoch 199, Validation set cost = 1.759109
# Epoch 200, Minibatch cost = 1.650932
# Epoch 200, Validation set cost = 1.765333
# Epoch 201, Minibatch cost = 1.811614
# Epoch 201, Validation set cost = 1.829023
# Epoch 202, Minibatch cost = 1.723359
# Epoch 202, Validation set cost = 1.800926
# Epoch 203, Minibatch cost = 1.777426
# Epoch 203, Validation set cost = 1.818513
# Epoch 204, Minibatch cost = 1.828091
# Epoch 204, Validation set cost = 1.815355
# Epoch 205, Minibatch cost = 1.705544
# Epoch 205, Validation set cost = 1.803506
# Epoch 206, Minibatch cost = 1.701387
# Epoch 206, Validation set cost = 1.827937
# Epoch 207, Minibatch cost = 1.809296
# Epoch 207, Validation set cost = 1.818890
# Epoch 208, Minibatch cost = 1.839105
# Epoch 208, Validation set cost = 1.873488
# Epoch 209, Minibatch cost = 1.768386
# Epoch 209, Validation set cost = 1.801150
# Epoch 210, Minibatch cost = 1.739610
# Epoch 210, Validation set cost = 1.774224
# Epoch 211, Minibatch cost = 1.740988
# Epoch 211, Validation set cost = 1.812369
# Epoch 212, Minibatch cost = 1.816225
# Epoch 212, Validation set cost = 1.787540
# Epoch 213, Minibatch cost = 1.744196
# Epoch 213, Validation set cost = 1.787451
# Epoch 214, Minibatch cost = 1.760360
# Epoch 214, Validation set cost = 1.785614
# Epoch 215, Minibatch cost = 1.806022
# Epoch 215, Validation set cost = 1.813483
# Epoch 216, Minibatch cost = 1.802637
# Epoch 216, Validation set cost = 1.837728
# Epoch 217, Minibatch cost = 1.795280
# Epoch 217, Validation set cost = 1.758576
# Epoch 218, Minibatch cost = 1.798173
# Epoch 218, Validation set cost = 1.749852
# Epoch 219, Minibatch cost = 1.843356
# Epoch 219, Validation set cost = 1.747332
# Epoch 220, Minibatch cost = 1.755353
# Epoch 220, Validation set cost = 1.774153
# Epoch 221, Minibatch cost = 1.748507
# Epoch 221, Validation set cost = 1.796037
# Epoch 222, Minibatch cost = 1.844717
# Epoch 222, Validation set cost = 1.836349
# Epoch 223, Minibatch cost = 1.812239
# Epoch 223, Validation set cost = 1.831484
# Epoch 224, Minibatch cost = 1.838485
# Epoch 224, Validation set cost = 1.766948
# Epoch 225, Minibatch cost = 1.857705
# Epoch 225, Validation set cost = 1.815895
# Epoch 226, Minibatch cost = 1.818635
# Epoch 226, Validation set cost = 1.807059
# Epoch 227, Minibatch cost = 1.816776
# Epoch 227, Validation set cost = 1.736179
# Epoch 228, Minibatch cost = 1.893857
# Epoch 228, Validation set cost = 1.757608
# Epoch 229, Minibatch cost = 1.814477
# Epoch 229, Validation set cost = 1.840069
# Epoch 230, Minibatch cost = 1.800297
# Epoch 230, Validation set cost = 1.786095
# Epoch 231, Minibatch cost = 1.825878
# Epoch 231, Validation set cost = 1.744604
# Epoch 232, Minibatch cost = 1.722949
# Epoch 232, Validation set cost = 1.778915
# Epoch 233, Minibatch cost = 1.820431
# Epoch 233, Validation set cost = 1.823442
# Epoch 234, Minibatch cost = 1.819539
# Epoch 234, Validation set cost = 1.831422
# Epoch 235, Minibatch cost = 1.770153
# Epoch 235, Validation set cost = 1.809707
# Epoch 236, Minibatch cost = 1.873956
# Epoch 236, Validation set cost = 1.811159
# Epoch 237, Minibatch cost = 1.851757
# Epoch 237, Validation set cost = 1.794932
# Epoch 238, Minibatch cost = 1.699595
# Epoch 238, Validation set cost = 1.763173
# Epoch 239, Minibatch cost = 1.675135
# Epoch 239, Validation set cost = 1.718564
# Epoch 240, Minibatch cost = 1.794466
# Epoch 240, Validation set cost = 1.851000
# Epoch 241, Minibatch cost = 1.819406
# Epoch 241, Validation set cost = 1.824869
# Epoch 242, Minibatch cost = 1.761521
# Epoch 242, Validation set cost = 1.751090
# Epoch 243, Minibatch cost = 1.665659
# Epoch 243, Validation set cost = 1.831045
# Epoch 244, Minibatch cost = 1.714179
# Epoch 244, Validation set cost = 1.864677
# Epoch 245, Minibatch cost = 1.764262
# Epoch 245, Validation set cost = 1.835482
# Epoch 246, Minibatch cost = 1.822570
# Epoch 246, Validation set cost = 1.845186
# Epoch 247, Minibatch cost = 1.735176
# Epoch 247, Validation set cost = 1.783516
# Epoch 248, Minibatch cost = 1.755696
# Epoch 248, Validation set cost = 1.797737
# Epoch 249, Minibatch cost = 1.708667
# Epoch 249, Validation set cost = 1.841740
# Epoch 250, Minibatch cost = 1.767298
# Epoch 250, Validation set cost = 1.857986
# Epoch 251, Minibatch cost = 1.800915
# Epoch 251, Validation set cost = 1.783586
# Epoch 252, Minibatch cost = 1.736301
# Epoch 252, Validation set cost = 1.838748
# Epoch 253, Minibatch cost = 1.794150
# Epoch 253, Validation set cost = 1.772765
# Epoch 254, Minibatch cost = 1.843888
# Epoch 254, Validation set cost = 1.812207
# Epoch 255, Minibatch cost = 1.848952
# Epoch 255, Validation set cost = 1.761095
# Epoch 256, Minibatch cost = 1.805191
# Epoch 256, Validation set cost = 1.787322
# Epoch 257, Minibatch cost = 1.840262
# Epoch 257, Validation set cost = 1.854216
# Epoch 258, Minibatch cost = 1.826344
# Epoch 258, Validation set cost = 1.781834
# Epoch 259, Minibatch cost = 1.858112
# Epoch 259, Validation set cost = 1.749054
# Epoch 260, Minibatch cost = 1.766307
# Epoch 260, Validation set cost = 1.747680
# Epoch 261, Minibatch cost = 1.694111
# Epoch 261, Validation set cost = 1.754260
# Epoch 262, Minibatch cost = 1.978436
# Epoch 262, Validation set cost = 1.765832
# Epoch 263, Minibatch cost = 1.745362
# Epoch 263, Validation set cost = 1.918613
# Epoch 264, Minibatch cost = 1.770215
# Epoch 264, Validation set cost = 1.746360
# Epoch 265, Minibatch cost = 1.768649
# Epoch 265, Validation set cost = 1.856393
# Epoch 266, Minibatch cost = 1.804617
# Epoch 266, Validation set cost = 1.808833
# Epoch 267, Minibatch cost = 1.741775
# Epoch 267, Validation set cost = 1.808335
# Epoch 268, Minibatch cost = 1.800985
# Epoch 268, Validation set cost = 1.785298
# Epoch 269, Minibatch cost = 1.813898
# Epoch 269, Validation set cost = 1.761782
# Epoch 270, Minibatch cost = 1.680085
# Epoch 270, Validation set cost = 1.768260
# Epoch 271, Minibatch cost = 1.745467
# Epoch 271, Validation set cost = 1.745797
# Epoch 272, Minibatch cost = 1.807407
# Epoch 272, Validation set cost = 1.767309
# Epoch 273, Minibatch cost = 1.726089
# Epoch 273, Validation set cost = 1.715024
# Epoch 274, Minibatch cost = 1.771813
# Epoch 274, Validation set cost = 1.732370
# Epoch 275, Minibatch cost = 1.768570
# Epoch 275, Validation set cost = 1.700690
# Epoch 276, Minibatch cost = 1.736679
# Epoch 276, Validation set cost = 1.733639
# Epoch 277, Minibatch cost = 1.802364
# Epoch 277, Validation set cost = 1.698934
# Epoch 278, Minibatch cost = 1.744853
# Epoch 278, Validation set cost = 1.764569
# Epoch 279, Minibatch cost = 1.743891
# Epoch 279, Validation set cost = 1.747168
# Epoch 280, Minibatch cost = 1.708217
# Epoch 280, Validation set cost = 1.729830
# Epoch 281, Minibatch cost = 1.727609
# Epoch 281, Validation set cost = 1.753444
# Epoch 282, Minibatch cost = 1.741798
# Epoch 282, Validation set cost = 1.800582
# Epoch 283, Minibatch cost = 1.693688
# Epoch 283, Validation set cost = 1.755103
# Epoch 284, Minibatch cost = 1.830994
# Epoch 284, Validation set cost = 1.728224
# Epoch 285, Minibatch cost = 1.748439
# Epoch 285, Validation set cost = 1.767968
# Epoch 286, Minibatch cost = 1.699239
# Epoch 286, Validation set cost = 1.740313
# Epoch 287, Minibatch cost = 1.809494
# Epoch 287, Validation set cost = 1.751669
# Epoch 288, Minibatch cost = 1.731368
# Epoch 288, Validation set cost = 1.747547
# Epoch 289, Minibatch cost = 1.731981
# Epoch 289, Validation set cost = 1.783691
# Epoch 290, Minibatch cost = 1.776846
# Epoch 290, Validation set cost = 1.797712
# Epoch 291, Minibatch cost = 1.880913
# Epoch 291, Validation set cost = 1.772826
# Epoch 292, Minibatch cost = 1.781907
# Epoch 292, Validation set cost = 1.791047
# Epoch 293, Minibatch cost = 1.837396
# Epoch 293, Validation set cost = 1.764807
# Epoch 294, Minibatch cost = 1.793281
# Epoch 294, Validation set cost = 1.724195
# Epoch 295, Minibatch cost = 1.759442
# Epoch 295, Validation set cost = 1.742033
# Epoch 296, Minibatch cost = 1.761416
# Epoch 296, Validation set cost = 1.724377
# Epoch 297, Minibatch cost = 1.892267
# Epoch 297, Validation set cost = 1.732103
# Epoch 298, Minibatch cost = 1.766221
# Epoch 298, Validation set cost = 1.742249
# Epoch 299, Minibatch cost = 1.760351
# Epoch 299, Validation set cost = 1.791653
# Epoch 300, Minibatch cost = 1.795093
# Epoch 300, Validation set cost = 1.758189
# Epoch 301, Minibatch cost = 1.790160
# Epoch 301, Validation set cost = 1.758378
# Epoch 302, Minibatch cost = 1.799137
# Epoch 302, Validation set cost = 1.730636
# Epoch 303, Minibatch cost = 1.744349
# Epoch 303, Validation set cost = 1.742507
# Epoch 304, Minibatch cost = 1.676419
# Epoch 304, Validation set cost = 1.789331
# Epoch 305, Minibatch cost = 1.789987
# Epoch 305, Validation set cost = 1.702125
# Epoch 306, Minibatch cost = 1.718997
# Epoch 306, Validation set cost = 1.776591
# Epoch 307, Minibatch cost = 1.737835
# Epoch 307, Validation set cost = 1.751400
# Epoch 308, Minibatch cost = 1.772763
# Epoch 308, Validation set cost = 1.794645
# Epoch 309, Minibatch cost = 1.711949
# Epoch 309, Validation set cost = 1.799452
# Epoch 310, Minibatch cost = 1.816313
# Epoch 310, Validation set cost = 1.823670
# Epoch 311, Minibatch cost = 1.706289
# Epoch 311, Validation set cost = 1.774195
# Epoch 312, Minibatch cost = 1.732192
# Epoch 312, Validation set cost = 1.753610
# Epoch 313, Minibatch cost = 1.788612
# Epoch 313, Validation set cost = 1.727637
# Epoch 314, Minibatch cost = 1.699240
# Epoch 314, Validation set cost = 1.724745
# Epoch 315, Minibatch cost = 1.718498
# Epoch 315, Validation set cost = 1.806302
# Epoch 316, Minibatch cost = 1.840456
# Epoch 316, Validation set cost = 1.744619
# Epoch 317, Minibatch cost = 1.736859
# Epoch 317, Validation set cost = 1.796020
# Epoch 318, Minibatch cost = 1.759796
# Epoch 318, Validation set cost = 1.727233
# Epoch 319, Minibatch cost = 1.813564
# Epoch 319, Validation set cost = 1.724579
# Epoch 320, Minibatch cost = 1.695995
# Epoch 320, Validation set cost = 1.783632
# Epoch 321, Minibatch cost = 1.846994
# Epoch 321, Validation set cost = 1.717873
# Epoch 322, Minibatch cost = 1.857705
# Epoch 322, Validation set cost = 1.757695
# Epoch 323, Minibatch cost = 1.731629
# Epoch 323, Validation set cost = 1.759443
# Epoch 324, Minibatch cost = 1.755889
# Epoch 324, Validation set cost = 1.740219
# Epoch 325, Minibatch cost = 1.693993
# Epoch 325, Validation set cost = 1.770201
# Epoch 326, Minibatch cost = 1.757041
# Epoch 326, Validation set cost = 1.756143
# Epoch 327, Minibatch cost = 1.728138
# Epoch 327, Validation set cost = 1.779025
# Epoch 328, Minibatch cost = 1.707318
# Epoch 328, Validation set cost = 1.784732
# Epoch 329, Minibatch cost = 1.689241
# Epoch 329, Validation set cost = 1.734248
# Epoch 330, Minibatch cost = 1.822153
# Epoch 330, Validation set cost = 1.774244
# Epoch 331, Minibatch cost = 1.873661
# Epoch 331, Validation set cost = 1.805275
# Epoch 332, Minibatch cost = 1.770149
# Epoch 332, Validation set cost = 1.795444
# Epoch 333, Minibatch cost = 1.767354
# Epoch 333, Validation set cost = 1.757925
# Epoch 334, Minibatch cost = 1.778170
# Epoch 334, Validation set cost = 1.795085
# Epoch 335, Minibatch cost = 1.745421
# Epoch 335, Validation set cost = 1.803551
# Epoch 336, Minibatch cost = 1.794587
# Epoch 336, Validation set cost = 1.761905
# Epoch 337, Minibatch cost = 1.788601
# Epoch 337, Validation set cost = 1.779453
# Epoch 338, Minibatch cost = 1.716879
# Epoch 338, Validation set cost = 1.761061
# Epoch 339, Minibatch cost = 1.730722
# Epoch 339, Validation set cost = 1.761729
# Epoch 340, Minibatch cost = 1.664235
# Epoch 340, Validation set cost = 1.777624
# Epoch 341, Minibatch cost = 1.776369
# Epoch 341, Validation set cost = 1.739236
# Epoch 342, Minibatch cost = 1.808619
# Epoch 342, Validation set cost = 1.805796
# Epoch 343, Minibatch cost = 1.804798
# Epoch 343, Validation set cost = 1.851881
# Epoch 344, Minibatch cost = 1.862907
# Epoch 344, Validation set cost = 1.838962
# Epoch 345, Minibatch cost = 1.723535
# Epoch 345, Validation set cost = 1.796422
# Epoch 346, Minibatch cost = 1.749506
# Epoch 346, Validation set cost = 1.753448
# Epoch 347, Minibatch cost = 1.868371
# Epoch 347, Validation set cost = 1.734021
# Epoch 348, Minibatch cost = 1.791887
# Epoch 348, Validation set cost = 1.760855
# Epoch 349, Minibatch cost = 1.772962
# Epoch 349, Validation set cost = 1.894280
# Epoch 350, Minibatch cost = 1.822096
# Epoch 350, Validation set cost = 1.754143
# Epoch 351, Minibatch cost = 1.716992
# Epoch 351, Validation set cost = 1.709280
# Epoch 352, Minibatch cost = 1.727247
# Epoch 352, Validation set cost = 1.751151
# Epoch 353, Minibatch cost = 1.769881
# Epoch 353, Validation set cost = 1.763442
# Epoch 354, Minibatch cost = 1.672795
# Epoch 354, Validation set cost = 1.738451
# Epoch 355, Minibatch cost = 1.684837
# Epoch 355, Validation set cost = 1.733065
# Epoch 356, Minibatch cost = 1.711067
# Epoch 356, Validation set cost = 1.728643
# Epoch 357, Minibatch cost = 1.768583
# Epoch 357, Validation set cost = 1.777921
# Epoch 358, Minibatch cost = 1.756337
# Epoch 358, Validation set cost = 1.766306
# Epoch 359, Minibatch cost = 1.743582
# Epoch 359, Validation set cost = 1.756521
# Epoch 360, Minibatch cost = 1.724755
# Epoch 360, Validation set cost = 1.787367
# Epoch 361, Minibatch cost = 1.782242
# Epoch 361, Validation set cost = 1.750299
# Epoch 362, Minibatch cost = 1.758473
# Epoch 362, Validation set cost = 1.737249
# Epoch 363, Minibatch cost = 1.769861
# Epoch 363, Validation set cost = 1.735485
# Epoch 364, Minibatch cost = 1.788561
# Epoch 364, Validation set cost = 1.744035
# Epoch 365, Minibatch cost = 1.716066
# Epoch 365, Validation set cost = 1.819793
# Epoch 366, Minibatch cost = 1.746326
# Epoch 366, Validation set cost = 1.761003
# Epoch 367, Minibatch cost = 1.816119
# Epoch 367, Validation set cost = 1.775385
# Epoch 368, Minibatch cost = 1.685211
# Epoch 368, Validation set cost = 1.717977
# Epoch 369, Minibatch cost = 1.755624
# Epoch 369, Validation set cost = 1.735513
# Epoch 370, Minibatch cost = 1.791578
# Epoch 370, Validation set cost = 1.761886
# Epoch 371, Minibatch cost = 1.786383
# Epoch 371, Validation set cost = 1.745037
# Epoch 372, Minibatch cost = 1.774747
# Epoch 372, Validation set cost = 1.756464
# Epoch 373, Minibatch cost = 1.746066
# Epoch 373, Validation set cost = 1.812082
# Epoch 374, Minibatch cost = 1.851087
# Epoch 374, Validation set cost = 1.774447
# Epoch 375, Minibatch cost = 1.705445
# Epoch 375, Validation set cost = 1.754987
# Epoch 376, Minibatch cost = 1.760500
# Epoch 376, Validation set cost = 1.812630
# Epoch 377, Minibatch cost = 1.675287
# Epoch 377, Validation set cost = 1.762871
# Epoch 378, Minibatch cost = 1.700358
# Epoch 378, Validation set cost = 1.850414
# Epoch 379, Minibatch cost = 1.757168
# Epoch 379, Validation set cost = 1.793682
# Epoch 380, Minibatch cost = 1.701016
# Epoch 380, Validation set cost = 1.791912
# Epoch 381, Minibatch cost = 1.729525
# Epoch 381, Validation set cost = 1.791875
# Epoch 382, Minibatch cost = 1.668251
# Epoch 382, Validation set cost = 1.788025
# Epoch 383, Minibatch cost = 1.702098
# Epoch 383, Validation set cost = 1.787423
# Epoch 384, Minibatch cost = 1.724037
# Epoch 384, Validation set cost = 1.759496
# Epoch 385, Minibatch cost = 1.793348
# Epoch 385, Validation set cost = 1.749224
# Epoch 386, Minibatch cost = 1.820056
# Epoch 386, Validation set cost = 1.776632
# Epoch 387, Minibatch cost = 1.702580
# Epoch 387, Validation set cost = 1.719093
# Epoch 388, Minibatch cost = 1.676644
# Epoch 388, Validation set cost = 1.729798
# Epoch 389, Minibatch cost = 1.792475
# Epoch 389, Validation set cost = 1.732113
# Epoch 390, Minibatch cost = 1.691203
# Epoch 390, Validation set cost = 1.714357
# Epoch 391, Minibatch cost = 1.680518
# Epoch 391, Validation set cost = 1.712532
# Epoch 392, Minibatch cost = 1.788716
# Epoch 392, Validation set cost = 1.745382
# Epoch 393, Minibatch cost = 1.799886
# Epoch 393, Validation set cost = 1.844565
# Epoch 394, Minibatch cost = 1.749465
# Epoch 394, Validation set cost = 1.769026
# Epoch 395, Minibatch cost = 1.633033
# Epoch 395, Validation set cost = 1.818443
# Epoch 396, Minibatch cost = 1.676458
# Epoch 396, Validation set cost = 1.758576
# Epoch 397, Minibatch cost = 1.709318
# Epoch 397, Validation set cost = 1.736619
# Epoch 398, Minibatch cost = 1.705688
# Epoch 398, Validation set cost = 1.758818
# Epoch 399, Minibatch cost = 1.799265
# Epoch 399, Validation set cost = 1.780281
# Epoch 400, Minibatch cost = 1.755351
# Epoch 400, Validation set cost = 1.742137
# Epoch 401, Minibatch cost = 1.687744
# Epoch 401, Validation set cost = 1.739988
# Epoch 402, Minibatch cost = 1.693831
# Epoch 402, Validation set cost = 1.734098
# Epoch 403, Minibatch cost = 1.752068
# Epoch 403, Validation set cost = 1.751038
# Epoch 404, Minibatch cost = 1.775622
# Epoch 404, Validation set cost = 1.756266
# Epoch 405, Minibatch cost = 1.724448
# Epoch 405, Validation set cost = 1.759296
# Epoch 406, Minibatch cost = 1.823551
# Epoch 406, Validation set cost = 1.762789
# Epoch 407, Minibatch cost = 1.678015
# Epoch 407, Validation set cost = 1.776006
# Epoch 408, Minibatch cost = 1.728680
# Epoch 408, Validation set cost = 1.806624
# Epoch 409, Minibatch cost = 1.688651
# Epoch 409, Validation set cost = 1.802068
# Epoch 410, Minibatch cost = 1.813500
# Epoch 410, Validation set cost = 1.873994
# Epoch 411, Minibatch cost = 1.766577
# Epoch 411, Validation set cost = 1.816479
# Epoch 412, Minibatch cost = 1.736411
# Epoch 412, Validation set cost = 1.746434
# Epoch 413, Minibatch cost = 1.747043
# Epoch 413, Validation set cost = 1.797980
# Epoch 414, Minibatch cost = 1.683080
# Epoch 414, Validation set cost = 1.768444
# Epoch 415, Minibatch cost = 1.737004
# Epoch 415, Validation set cost = 1.787634
# Epoch 416, Minibatch cost = 1.871523
# Epoch 416, Validation set cost = 1.759716
# Epoch 417, Minibatch cost = 1.708583
# Epoch 417, Validation set cost = 1.844937
# Epoch 418, Minibatch cost = 1.772635
# Epoch 418, Validation set cost = 1.778836
# Epoch 419, Minibatch cost = 1.772961
# Epoch 419, Validation set cost = 1.757059
# Epoch 420, Minibatch cost = 1.767848
# Epoch 420, Validation set cost = 1.750097
# Epoch 421, Minibatch cost = 1.727678
# Epoch 421, Validation set cost = 1.766152
# Epoch 422, Minibatch cost = 1.717200
# Epoch 422, Validation set cost = 1.751923
# Epoch 423, Minibatch cost = 1.756957
# Epoch 423, Validation set cost = 1.784608
# Epoch 424, Minibatch cost = 1.719622
# Epoch 424, Validation set cost = 1.758717
# Epoch 425, Minibatch cost = 1.765805
# Epoch 425, Validation set cost = 1.735771
# Epoch 426, Minibatch cost = 1.786406
# Epoch 426, Validation set cost = 1.743315
# Epoch 427, Minibatch cost = 1.787684
# Epoch 427, Validation set cost = 1.790609
# Epoch 428, Minibatch cost = 1.788381
# Epoch 428, Validation set cost = 1.846209
# Epoch 429, Minibatch cost = 1.768929
# Epoch 429, Validation set cost = 1.841990
# Epoch 430, Minibatch cost = 1.811097
# Epoch 430, Validation set cost = 1.776022
# Epoch 431, Minibatch cost = 1.710492
# Epoch 431, Validation set cost = 1.739614
# Epoch 432, Minibatch cost = 1.770807
# Epoch 432, Validation set cost = 1.767125
# Epoch 433, Minibatch cost = 1.687209
# Epoch 433, Validation set cost = 1.802647
# Epoch 434, Minibatch cost = 1.663699
# Epoch 434, Validation set cost = 1.739198
# Epoch 435, Minibatch cost = 1.731493
# Epoch 435, Validation set cost = 1.777008
# Epoch 436, Minibatch cost = 1.677821
# Epoch 436, Validation set cost = 1.770051
# Epoch 437, Minibatch cost = 1.659809
# Epoch 437, Validation set cost = 1.765499
# Epoch 438, Minibatch cost = 1.711610
# Epoch 438, Validation set cost = 1.897425
# Epoch 439, Minibatch cost = 1.695482
# Epoch 439, Validation set cost = 1.834854
# Epoch 440, Minibatch cost = 1.818877
# Epoch 440, Validation set cost = 1.803798
# Epoch 441, Minibatch cost = 1.733395
# Epoch 441, Validation set cost = 1.840743
# Epoch 442, Minibatch cost = 1.745374
# Epoch 442, Validation set cost = 1.755870
# Epoch 443, Minibatch cost = 1.815064
# Epoch 443, Validation set cost = 1.771685
# Epoch 444, Minibatch cost = 1.825596
# Epoch 444, Validation set cost = 1.729487
# Epoch 445, Minibatch cost = 1.743157
# Epoch 445, Validation set cost = 1.758022
# Epoch 446, Minibatch cost = 1.658337
# Epoch 446, Validation set cost = 1.776273
# Epoch 447, Minibatch cost = 1.675699
# Epoch 447, Validation set cost = 1.728419
# Epoch 448, Minibatch cost = 1.730766
# Epoch 448, Validation set cost = 1.751718
# Epoch 449, Minibatch cost = 1.662897
# Epoch 449, Validation set cost = 1.757337
# Epoch 450, Minibatch cost = 1.734522
# Epoch 450, Validation set cost = 1.766760
# Epoch 451, Minibatch cost = 1.856734
# Epoch 451, Validation set cost = 1.753410
# Epoch 452, Minibatch cost = 1.717909
# Epoch 452, Validation set cost = 1.804935
# Epoch 453, Minibatch cost = 1.728159
# Epoch 453, Validation set cost = 1.747280
# Epoch 454, Minibatch cost = 1.662639
# Epoch 454, Validation set cost = 1.829963
# Epoch 455, Minibatch cost = 1.750786
# Epoch 455, Validation set cost = 1.839577
# Epoch 456, Minibatch cost = 1.757150
# Epoch 456, Validation set cost = 1.740450
# Epoch 457, Minibatch cost = 1.718474
# Epoch 457, Validation set cost = 1.750506
# Epoch 458, Minibatch cost = 1.690123
# Epoch 458, Validation set cost = 1.729011
# Epoch 459, Minibatch cost = 1.746460
# Epoch 459, Validation set cost = 1.743387
# Epoch 460, Minibatch cost = 1.742641
# Epoch 460, Validation set cost = 1.765431
# Epoch 461, Minibatch cost = 1.741510
# Epoch 461, Validation set cost = 1.717768
# Epoch 462, Minibatch cost = 1.704105
# Epoch 462, Validation set cost = 1.759418
# Epoch 463, Minibatch cost = 1.791992
# Epoch 463, Validation set cost = 1.729789
# Epoch 464, Minibatch cost = 1.640475
# Epoch 464, Validation set cost = 1.770034
# Epoch 465, Minibatch cost = 1.752320
# Epoch 465, Validation set cost = 1.781654
# Epoch 466, Minibatch cost = 1.785605
# Epoch 466, Validation set cost = 1.774225
# Epoch 467, Minibatch cost = 1.746338
# Epoch 467, Validation set cost = 1.762356
# Epoch 468, Minibatch cost = 1.745954
# Epoch 468, Validation set cost = 1.781935
# Epoch 469, Minibatch cost = 1.704366
# Epoch 469, Validation set cost = 1.747710
# Epoch 470, Minibatch cost = 1.724829
# Epoch 470, Validation set cost = 1.756115
# Epoch 471, Minibatch cost = 1.834691
# Epoch 471, Validation set cost = 1.712973
# Epoch 472, Minibatch cost = 1.731169
# Epoch 472, Validation set cost = 1.728547
# Epoch 473, Minibatch cost = 1.836133
# Epoch 473, Validation set cost = 1.744225
# Epoch 474, Minibatch cost = 1.693173
# Epoch 474, Validation set cost = 1.755210
# Epoch 475, Minibatch cost = 1.707754
# Epoch 475, Validation set cost = 1.729244
# Epoch 476, Minibatch cost = 1.685624
# Epoch 476, Validation set cost = 1.725400
# Epoch 477, Minibatch cost = 1.692529
# Epoch 477, Validation set cost = 1.712467
# Epoch 478, Minibatch cost = 1.804537
# Epoch 478, Validation set cost = 1.761274
# Epoch 479, Minibatch cost = 1.710422
# Epoch 479, Validation set cost = 1.750935
# Epoch 480, Minibatch cost = 1.741267
# Epoch 480, Validation set cost = 1.776980
# Epoch 481, Minibatch cost = 1.738077
# Epoch 481, Validation set cost = 1.764661
# Epoch 482, Minibatch cost = 1.693397
# Epoch 482, Validation set cost = 1.742683
# Epoch 483, Minibatch cost = 1.839347
# Epoch 483, Validation set cost = 1.775753
# Epoch 484, Minibatch cost = 1.812406
# Epoch 484, Validation set cost = 1.729306
# Epoch 485, Minibatch cost = 1.872538
# Epoch 485, Validation set cost = 1.873114
# Epoch 486, Minibatch cost = 1.761642
# Epoch 486, Validation set cost = 1.755357
# Epoch 487, Minibatch cost = 1.746443
# Epoch 487, Validation set cost = 1.728525
# Epoch 488, Minibatch cost = 1.749043
# Epoch 488, Validation set cost = 1.750131
# Epoch 489, Minibatch cost = 1.810717
# Epoch 489, Validation set cost = 1.746263
# Epoch 490, Minibatch cost = 1.758895
# Epoch 490, Validation set cost = 1.788478
# Epoch 491, Minibatch cost = 1.688565
# Epoch 491, Validation set cost = 1.779307
# Epoch 492, Minibatch cost = 1.752410
# Epoch 492, Validation set cost = 1.740443
# Epoch 493, Minibatch cost = 1.665172
# Epoch 493, Validation set cost = 1.747074
# Epoch 494, Minibatch cost = 1.761693
# Epoch 494, Validation set cost = 1.729311
# Epoch 495, Minibatch cost = 1.660815
# Epoch 495, Validation set cost = 1.718191
# Epoch 496, Minibatch cost = 1.640551
# Epoch 496, Validation set cost = 1.722111
# Epoch 497, Minibatch cost = 1.730717
# Epoch 497, Validation set cost = 1.767217
# Epoch 498, Minibatch cost = 1.676733
# Epoch 498, Validation set cost = 1.687211
# Epoch 499, Minibatch cost = 1.648677
# Epoch 499, Validation set cost = 1.744086
# Model saved in file: ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
#
# Current validation performance:
#
# Displaying graph for dataseries 0:
# Displaying graph for dataseries 1:

# %%
 filename = 'predict_window_50-2.csv'
seed = x_train[101]
predictions = generate_prediction(seed, 5000, restore_path=model_path, progress_counter=20)
np.savetxt(filename, predictions, delimiter=",")
# Out:
# INFO:tensorflow:Restoring parameters from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt
# Model successfully restored from ModelCheckpoints/four_border_distance_pred_delta_xy-64-all.ckpt.
# Generating sequence.
# Generated 0 of 5000 data points.
# Generated 250 of 5000 data points.
# Generated 500 of 5000 data points.
# Generated 750 of 5000 data points.
# Generated 1000 of 5000 data points.
# Generated 1250 of 5000 data points.
# Generated 1500 of 5000 data points.
# Generated 1750 of 5000 data points.
# Generated 2000 of 5000 data points.
# Generated 2250 of 5000 data points.
# Generated 2500 of 5000 data points.
# Generated 2750 of 5000 data points.
# Generated 3000 of 5000 data points.
# Generated 3250 of 5000 data points.
# Generated 3500 of 5000 data points.
# Generated 3750 of 5000 data points.
# Generated 4000 of 5000 data points.
# Generated 4250 of 5000 data points.
# Generated 4500 of 5000 data points.
# Generated 4750 of 5000 data points.
# Done!
